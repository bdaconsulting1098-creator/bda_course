# %% [markdown]
# # Python Training
# # Contents
# - [Import modules](#Import-modules)
# - [Object Creation](#Object-Creation)
# - [Viewing Data](#Viewing-Data)
# - [Selection](#Selection)
# - [Selection by Position](#Selection-by-Position)
# - [Boolean Indexing](#Boolean-Indexing)
# - [Setting](#Setting)
# - [Missing Data](#Missing-Data)
# - [Operations](#Operations)
# - [Merge](#Merge)
# - [Grouping](#Grouping)
# - [Reshaping](#Reshaping)
# - [Time Series](#Time-Series)
# - [Categoricals](#Categoricals)
# - [Time Series](#Time-Series)
# - [Plotting](#Plotting)
# - [Getting Data In/Out](#Getting-Data-In/Out)
# - [Error Handling](#Error-Handling)
# - [Function](#Function)

# %% [markdown]
# # Import modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %pip install pandasql --user
from pandasql import sqldf
# Out:
# ...
#
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26781 sha256=817b81f53bee99a4aa21b3dcc1910001dd21f5dbc565ab52e5ea15bf7f980bc0
#   Stored in directory: c:\users\abc\appdata\local\pip\cache\wheels\63\e8\ec\75b1df467ecf57b6ececb32cb16f4e86697cbfe55cb0c51f07
# Successfully built pandasql
# ...

# %% [markdown]
# # Object Creation
#  Creating a Series by passing a list of values, letting pandas create a default integer index:

# %%
Series
DataFrame
list
dict
array
index

# %%
list [1,2,'erw']   dictionary {'a':1, 'b':3} 
array([[-0.48479077, -0.51541263,  1.02174233,  0.2940478 ],
       [ 0.00671131, -1.73351438,  1.50997736,  1.48942854],
       [ 0.64740529,  0.1355594 , -1.04325823,  0.36031536],
       [ 1.37617244, -2.41264344,  1.18923317, -0.35403184],
       [ 0.37270292, -0.17271254, -1.03702008,  0.3676547 ],
       [ 0.49852348,  0.85627004, -0.84514847,  0.63807985]])

# %%
pd.Series([1,3,5,np.nan,6,8])

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s

# %% [markdown]
# Creating a [DataFrame] by passing a numpy array, with a datetime index and labeled columns:

# %%
pd.date_range('20141101', periods=6)

# %%
dates = pd.date_range('20141101', periods=6)
dates

# %%
np.random.randn(6,4)
# Out:
# array([[-0.48479077, -0.51541263,  1.02174233,  0.2940478 ],
#        [ 0.00671131, -1.73351438,  1.50997736,  1.48942854],
#        [ 0.64740529,  0.1355594 , -1.04325823,  0.36031536],
#        [ 1.37617244, -2.41264344,  1.18923317, -0.35403184],
#        [ 0.37270292, -0.17271254, -1.03702008,  0.3676547 ],
#        [ 0.49852348,  0.85627004, -0.84514847,  0.63807985]])

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates,columns=['one','two','three','four'])
df
# Out:
#                  one       two     three      four
# dates
# 2014-11-01  1.282878  1.859800  1.050713  0.942618
# 2014-11-02  0.765643  0.735878  1.589891 -0.531448
# 2014-11-03  0.758041 -1.034167  1.100249  0.678100
# 2014-11-04  0.539934  0.730257 -0.858822 -1.133150
# 2014-11-05  0.606519  0.017875  2.958902  0.337166
# 2014-11-06  0.187048 -1.796126 -1.140436  0.856097

# %%
df.index.rename('dates',inplace=True)
df['ID'] = range(1, len(df) + 1)

# %% [markdown]
# CREATE TABLE temp(one float,two float,three float,four float)
#
# insert into temp (one ,two ,three,four)
#
# VALUES
# (-0.82635,	-1.422438,	1.617015,	-1.465993),
# (1.279714,	-0.264422,	0.206226,	0.707471)

# %% [markdown]
# Creating a DataFrame by passing a dict of objects that can be converted to series-like.

# %%
df2 = pd.DataFrame({ 'A' : 1.,
                        'B' : pd.Timestamp('20130102'),
                        'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                        'D' : np.array([3] * 4,dtype='int32'),
                        'E' : pd.Categorical(["test","train","test","train"]),
                        'F' : 'foo' })
   
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# Having specific [dtypes]:

# %%
list(range(4))
# Out:
# [0, 1, 2, 3]

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# # Viewing Data
# See the top & bottom rows of the frame

# %%
df.

# %%
df.head()
# Out:
# <bound method NDFrame.head of                  one       two     three      four
# 2014-11-01 -0.826359 -1.422438  1.617015 -1.465993
# 2014-11-02  1.279714 -0.264422  0.206226  0.707471
# 2014-11-03  1.056507 -0.804262  0.762899  1.005693
# 2014-11-04  1.199555  1.033413 -0.450919  0.113587
# 2014-11-05  1.069675  0.149181 -0.012881 -0.503559
# 2014-11-06  0.094150 -0.387608  0.761176  1.658888>

# %%
sqldf('select * from df limit 10')
# Out:
#                         dates       one       two     three      four  ID
# 0  2014-11-01 00:00:00.000000 -0.826359 -1.422438  1.617015 -1.465993   1
# 1  2014-11-02 00:00:00.000000  1.279714 -0.264422  0.206226  0.707471   2
# 2  2014-11-03 00:00:00.000000  1.056507 -0.804262  0.762899  1.005693   3
# 3  2014-11-04 00:00:00.000000  1.199555  1.033413 -0.450919  0.113587   4
# 4  2014-11-05 00:00:00.000000  1.069675  0.149181 -0.012881 -0.503559   5
# 5  2014-11-06 00:00:00.000000  0.094150 -0.387608  0.761176  1.658888   6

# %%
df.tail(3)
# Out:
# <bound method NDFrame.tail of                  one       two     three      four
# 2014-11-01 -0.826359 -1.422438  1.617015 -1.465993
# 2014-11-02  1.279714 -0.264422  0.206226  0.707471
# 2014-11-03  1.056507 -0.804262  0.762899  1.005693
# 2014-11-04  1.199555  1.033413 -0.450919  0.113587
# 2014-11-05  1.069675  0.149181 -0.012881 -0.503559
# 2014-11-06  0.094150 -0.387608  0.761176  1.658888>

# %% [markdown]
# Display the index, columns, and the underlying numpy data

# %%
df.index
# Out:
# DatetimeIndex(['2014-11-01', '2014-11-02', '2014-11-03', '2014-11-04',
#                '2014-11-05', '2014-11-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['one', 'two', 'three', 'four'], dtype='object')

# %%
df.values
# Out:
# array([[-0.82635923, -1.42243837,  1.61701481, -1.46599274],
#        [ 1.27971416, -0.264422  ,  0.2062259 ,  0.70747095],
#        [ 1.05650676, -0.80426217,  0.76289887,  1.00569298],
#        [ 1.19955489,  1.03341308, -0.45091881,  0.11358701],
#        [ 1.06967454,  0.14918108, -0.01288122, -0.50355911],
#        [ 0.09415031, -0.38760777,  0.76117597,  1.65888843]])

# %% [markdown]
# Describe shows a quick statistic summary of your data

# %%
df.describe()
# Out:
#             one       two     three      four
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.645540 -0.282689  0.480586  0.252681
# std    0.840049  0.836785  0.726139  1.122173
# min   -0.826359 -1.422438 -0.450919 -1.465993
# 25%    0.334739 -0.700099  0.041896 -0.349273
# 50%    1.063091 -0.326015  0.483701  0.410529
# 75%    1.167085  0.045780  0.762468  0.931137
# max    1.279714  1.033413  1.617015  1.658888

# %% [markdown]
# Transposing your data

# %%
df.T
# Out:
#        2014-11-01  2014-11-02  2014-11-03  2014-11-04  2014-11-05  2014-11-06
# one     -0.826359    1.279714    1.056507    1.199555    1.069675    0.094150
# two     -1.422438   -0.264422   -0.804262    1.033413    0.149181   -0.387608
# three    1.617015    0.206226    0.762899   -0.450919   -0.012881    0.761176
# four    -1.465993    0.707471    1.005693    0.113587   -0.503559    1.658888

# %% [markdown]
# Sorting by an axis (In this case, sorting the columns in reverse alphabetical order):

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#                  one       two     three      four
# 2014-11-06  0.094150 -0.387608  0.761176  1.658888
# 2014-11-05  1.069675  0.149181 -0.012881 -0.503559
# 2014-11-04  1.199555  1.033413 -0.450919  0.113587
# 2014-11-03  1.056507 -0.804262  0.762899  1.005693
# 2014-11-02  1.279714 -0.264422  0.206226  0.707471
# 2014-11-01 -0.826359 -1.422438  1.617015 -1.465993

# %% [markdown]
# Sorting by values

# %%
df.sort_values(by='two',ascending=False)
# Out:
#                  one       two     three      four
# 2014-11-04  1.199555  1.033413 -0.450919  0.113587
# 2014-11-05  1.069675  0.149181 -0.012881 -0.503559
# 2014-11-02  1.279714 -0.264422  0.206226  0.707471
# 2014-11-06  0.094150 -0.387608  0.761176  1.658888
# 2014-11-03  1.056507 -0.804262  0.762899  1.005693
# 2014-11-01 -0.826359 -1.422438  1.617015 -1.465993

# %%
sqldf('select * from df order by two desc')
# Out:
#                         dates       one       two     three      four  ID
# 0  2014-11-04 00:00:00.000000  1.199555  1.033413 -0.450919  0.113587   4
# 1  2014-11-05 00:00:00.000000  1.069675  0.149181 -0.012881 -0.503559   5
# 2  2014-11-02 00:00:00.000000  1.279714 -0.264422  0.206226  0.707471   2
# 3  2014-11-06 00:00:00.000000  0.094150 -0.387608  0.761176  1.658888   6
# 4  2014-11-03 00:00:00.000000  1.056507 -0.804262  0.762899  1.005693   3
# 5  2014-11-01 00:00:00.000000 -0.826359 -1.422438  1.617015 -1.465993   1

# %% [markdown]
# # Selection

# %% [markdown]
# Note While standard Python / Numpy expressions for selecting and setting are intuitive and come in handy for interactive work, for production code, we recommend the optimized pandas data access methods, .at, .iat, .loc, .iloc and .ix.

# %% [markdown]
# ## Getting

# %% [markdown]
# Selecting a single column, which yields a Series, equivalent to df.one

# %%
df['one']
# Out:
# 2014-11-01   -0.826359
# 2014-11-02    1.279714
# 2014-11-03    1.056507
# 2014-11-04    1.199555
# 2014-11-05    1.069675
# 2014-11-06    0.094150
# Freq: D, Name: one, dtype: float64

# %%
# df.index.rename('dates',inplace=True)
# df['ID'] = range(1, len(df) + 1)

# %%
sqldf("select dates,one from df")
# Out:
#                         dates       one
# 0  2014-11-01 00:00:00.000000 -0.826359
# 1  2014-11-02 00:00:00.000000  1.279714
# 2  2014-11-03 00:00:00.000000  1.056507
# 3  2014-11-04 00:00:00.000000  1.199555
# 4  2014-11-05 00:00:00.000000  1.069675
# 5  2014-11-06 00:00:00.000000  0.094150

# %%
df['two']
# Out:
# 2014-11-01   -1.422438
# 2014-11-02   -0.264422
# 2014-11-03   -0.804262
# 2014-11-04    1.033413
# 2014-11-05    0.149181
# 2014-11-06   -0.387608
# Freq: D, Name: two, dtype: float64

# %%
df.one
# Out:
# 2014-11-01   -0.826359
# 2014-11-02    1.279714
# 2014-11-03    1.056507
# 2014-11-04    1.199555
# 2014-11-05    1.069675
# 2014-11-06    0.094150
# Freq: D, Name: one, dtype: float64

# %% [markdown]
# Selecting via [], which slices the rows.

# %%
df[0:5]
# Out:
#                  one       two     three      four
# 2014-11-01 -0.826359 -1.422438  1.617015 -1.465993
# 2014-11-02  1.279714 -0.264422  0.206226  0.707471
# 2014-11-03  1.056507 -0.804262  0.762899  1.005693
# 2014-11-04  1.199555  1.033413 -0.450919  0.113587
# 2014-11-05  1.069675  0.149181 -0.012881 -0.503559

# %%
sqldf('select  * from df LIMIT 5')
# Out:
#                         dates       one       two     three      four  ID
# 0  2014-11-01 00:00:00.000000 -0.826359 -1.422438  1.617015 -1.465993   1
# 1  2014-11-02 00:00:00.000000  1.279714 -0.264422  0.206226  0.707471   2
# 2  2014-11-03 00:00:00.000000  1.056507 -0.804262  0.762899  1.005693   3
# 3  2014-11-04 00:00:00.000000  1.199555  1.033413 -0.450919  0.113587   4
# 4  2014-11-05 00:00:00.000000  1.069675  0.149181 -0.012881 -0.503559   5

# %%
df[0:5:2]
# Out:
#                  one       two     three      four  ID
# dates
# 2014-11-01 -0.826359 -1.422438  1.617015 -1.465993   1
# 2014-11-03  1.056507 -0.804262  0.762899  1.005693   3
# 2014-11-05  1.069675  0.149181 -0.012881 -0.503559   5

# %%
sqldf('select  * from df where ID % 2 <>0 ')
# Out:
#                         dates       one       two     three      four  ID
# 0  2014-11-01 00:00:00.000000 -0.826359 -1.422438  1.617015 -1.465993   1
# 1  2014-11-03 00:00:00.000000  1.056507 -0.804262  0.762899  1.005693   3
# 2  2014-11-05 00:00:00.000000  1.069675  0.149181 -0.012881 -0.503559   5

# %%
df['20141102':'20141104':2]
# Out:
#                  one       two     three      four
# 2014-11-02  1.279714 -0.264422  0.206226  0.707471
# 2014-11-04  1.199555  1.033413 -0.450919  0.113587

# %% [markdown]
# ## Selecting by Label

# %% [markdown]
# For getting a cross section using a label

# %%
df.loc[dates[0]]
# Out:
# one     -0.826359
# two     -1.422438
# three    1.617015
# four    -1.465993
# Name: 2014-11-01 00:00:00, dtype: float64

# %%
df.index.rename('dates',inplace=True)
sqldf('select * from df where dates="2014-11-01 00:00:00.000000"')
# Out:
#                         dates       one       two     three      four
# 0  2014-11-01 00:00:00.000000 -0.826359 -1.422438  1.617015 -1.465993

# %% [markdown]
# Selecting on a multi-axis by label

# %%
df.loc[:,['one','two']]
# Out:
#                  one       two
# dates
# 2014-11-01 -0.826359 -1.422438
# 2014-11-02  1.279714 -0.264422
# 2014-11-03  1.056507 -0.804262
# 2014-11-04  1.199555  1.033413
# 2014-11-05  1.069675  0.149181
# 2014-11-06  0.094150 -0.387608

# %%
sqldf('select dates,one,two from df')
# Out:
#                         dates       one       two
# 0  2014-11-01 00:00:00.000000 -0.826359 -1.422438
# 1  2014-11-02 00:00:00.000000  1.279714 -0.264422
# 2  2014-11-03 00:00:00.000000  1.056507 -0.804262
# 3  2014-11-04 00:00:00.000000  1.199555  1.033413
# 4  2014-11-05 00:00:00.000000  1.069675  0.149181
# 5  2014-11-06 00:00:00.000000  0.094150 -0.387608

# %% [markdown]
# Showing label slicing, both endpoints are included

# %%
df.loc['20141102':'20141104',['one','two']]
# Out:
# pandas.core.frame.DataFrame

# %%
sqldf('select dates,one,two from df where date(dates) between "2014-11-02" and "2014-11-04"')
# Out:
#                         dates       one       two
# 0  2014-11-02 00:00:00.000000  1.279714 -0.264422
# 1  2014-11-03 00:00:00.000000  1.056507 -0.804262
# 2  2014-11-04 00:00:00.000000  1.199555  1.033413

# %% [markdown]
# Reduction in the dimensions of the returned object

# %%
df.loc['20141102',['one','two']]
# Out:
# one    1.279714
# two   -0.264422
# Name: 2014-11-02 00:00:00, dtype: float64

# %%
sqldf('select dates,one,two from df where date(dates) = "2014-11-02" ')
# Out:
#                         dates       one       two
# 0  2014-11-02 00:00:00.000000  1.279714 -0.264422

# %% [markdown]
# For getting a scalar value

# %%
df.loc[dates[0],'one']
# Out:
# -0.8263592301522819

# %%
df['ID'] = range(1, len(df) + 1)

# %%
df
# Out:
#                  one       two     three      four  ID
# dates
# 2014-11-01 -0.826359 -1.422438  1.617015 -1.465993   1
# 2014-11-02  1.279714 -0.264422  0.206226  0.707471   2
# 2014-11-03  1.056507 -0.804262  0.762899  1.005693   3
# 2014-11-04  1.199555  1.033413 -0.450919  0.113587   4
# 2014-11-05  1.069675  0.149181 -0.012881 -0.503559   5
# 2014-11-06  0.094150 -0.387608  0.761176  1.658888   6

# %%
sqldf('select one from df where ID =1').values[0][0]
# Out:
# -0.8263592301522819

# %% [markdown]
# For getting fast access to a scalar (equiv to the prior method)

# %%
df.at[dates[0],'one']
# Out:
# -0.8263592301522819

# %% [markdown]
# ## Selection by Position

# %% [markdown]
# See more in [Selection by Position](Selection by Position)
#
# Select via the position of the passed integers

# %%
df.iloc[3]
# Out:
# one      1.199555
# two      1.033413
# three   -0.450919
# four     0.113587
# ID       4.000000
# Name: 2014-11-04 00:00:00, dtype: float64

# %%
sqldf('select * from df where ID =4')
# Out:
#                         dates       one       two     three      four  ID
# 0  2014-11-04 00:00:00.000000  1.199555  1.033413 -0.450919  0.113587   4

# %% [markdown]
# By integer slices, acting similar to numpy/python

# %% [markdown]
# By lists of integer position locations, similar to the numpy/python style

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                  one     three
# dates
# 2014-11-02  1.279714  0.206226
# 2014-11-03  1.056507  0.762899
# 2014-11-05  1.069675 -0.012881

# %%
sqldf('select dates,one,three from df where ID in (2,3,5)')
# Out:
#                         dates       one     three
# 0  2014-11-02 00:00:00.000000  1.279714  0.206226
# 1  2014-11-03 00:00:00.000000  1.056507  0.762899
# 2  2014-11-05 00:00:00.000000  1.069675 -0.012881

# %% [markdown]
# For slicing rows explicitly

# %%
df
# Out:
#                  one       two     three      four  ID
# dates
# 2014-11-01 -0.826359 -1.422438  1.617015 -1.465993   1
# 2014-11-02  1.279714 -0.264422  0.206226  0.707471   2
# 2014-11-03  1.056507 -0.804262  0.762899  1.005693   3
# 2014-11-04  1.199555  1.033413 -0.450919  0.113587   4
# 2014-11-05  1.069675  0.149181 -0.012881 -0.503559   5
# 2014-11-06  0.094150 -0.387608  0.761176  1.658888   6

# %%
df.iloc[1:3,:]
# Out:
#                  one       two     three      four  ID
# dates
# 2014-11-02  1.279714 -0.264422  0.206226  0.707471   2
# 2014-11-03  1.056507 -0.804262  0.762899  1.005693   3

# %%
sqldf('select * from df where ID between 2 and 3')
# Out:
#                         dates       one       two     three      four  ID
# 0  2014-11-02 00:00:00.000000  1.279714 -0.264422  0.206226  0.707471   2
# 1  2014-11-03 00:00:00.000000  1.056507 -0.804262  0.762899  1.005693   3

# %% [markdown]
# For slicing columns explicitly

# %%
df.iloc[:,1:3]
# Out:
#                  two     three
# dates
# 2014-11-01 -1.422438  1.617015
# 2014-11-02 -0.264422  0.206226
# 2014-11-03 -0.804262  0.762899
# 2014-11-04  1.033413 -0.450919
# 2014-11-05  0.149181 -0.012881
# 2014-11-06 -0.387608  0.761176

# %%
sqldf('select two,three from df')
# Out:
#         two     three
# 0 -1.422438  1.617015
# 1 -0.264422  0.206226
# 2 -0.804262  0.762899
# 3  1.033413 -0.450919
# 4  0.149181 -0.012881
# 5 -0.387608  0.761176

# %% [markdown]
# For getting a value explicitly

# %%
df.iloc[1,1]
# Out:
# -0.26442200008156025

# %%
sqldf('select two from df where ID = 2').values[0][0]
# Out:
# -0.26442200008156025

# %% [markdown]
# For getting fast access to a scalar (equiv to the prior method)

# %%
df.iat[0,0]
# Out:
# -0.8263592301522819

# %%
sqldf('select one from df where ID = 1').values[0][0]
# Out:
# -0.8263592301522819

# %% [markdown]
# ## Boolean Indexing
# Using a single column’s values to select data.

# %%
df[df.one > 0.5]
# Out:
#                  one       two     three      four  ID
# dates
# 2014-11-02  1.279714 -0.264422  0.206226  0.707471   2
# 2014-11-03  1.056507 -0.804262  0.762899  1.005693   3
# 2014-11-04  1.199555  1.033413 -0.450919  0.113587   4
# 2014-11-05  1.069675  0.149181 -0.012881 -0.503559   5

# %%
sqldf('select * from df where one>0.5')
# Out:
#                         dates       one       two     three      four  ID
# 0  2014-11-02 00:00:00.000000  1.279714 -0.264422  0.206226  0.707471   2
# 1  2014-11-03 00:00:00.000000  1.056507 -0.804262  0.762899  1.005693   3
# 2  2014-11-04 00:00:00.000000  1.199555  1.033413 -0.450919  0.113587   4
# 3  2014-11-05 00:00:00.000000  1.069675  0.149181 -0.012881 -0.503559   5

# %% [markdown]
# Selecting values from a DataFrame where a boolean condition is met.

# %%
df[df>0]
# Out:
#                  one       two     three      four  ID
# dates
# 2014-11-01       NaN       NaN  1.617015       NaN   1
# 2014-11-02  1.279714       NaN  0.206226  0.707471   2
# 2014-11-03  1.056507       NaN  0.762899  1.005693   3
# 2014-11-04  1.199555  1.033413       NaN  0.113587   4
# 2014-11-05  1.069675  0.149181       NaN       NaN   5
# 2014-11-06  0.094150       NaN  0.761176  1.658888   6

# %%
sqldf('''select case when one >0 then one else null end as one,
      case when two > 0 then two else null end as two from df''')
# Out:
#         one       two
# 0       NaN       NaN
# 1  1.279714       NaN
# 2  1.056507       NaN
# 3  1.199555  1.033413
# 4  1.069675  0.149181
# 5  0.094150       NaN

# %% [markdown]
# Using the isin method for filtering:

# %%
df2 = df.copy()
df2['five'] = ['one', 'one','two','three','four','three']
df2
# Out:
#                  one       two     three      four  ID   five
# dates
# 2014-11-01 -0.826359 -1.422438  1.617015 -1.465993   1    one
# 2014-11-02  1.279714 -0.264422  0.206226  0.707471   2    one
# 2014-11-03  1.056507 -0.804262  0.762899  1.005693   3    two
# 2014-11-04  1.199555  1.033413 -0.450919  0.113587   4  three
# 2014-11-05  1.069675  0.149181 -0.012881 -0.503559   5   four
# 2014-11-06  0.094150 -0.387608  0.761176  1.658888   6  three

# %% [markdown]
# DROP table  IF EXISTS temp
#
# CREATE TABLE temp(idx int, one float,two float,three float,four float)
#
# insert into temp (idx,one ,two ,three,four)
#
# VALUES
# (1,-0.82635,	-1.422438,	1.617015,	-1.465993),
# (2,1.279714,	-0.264422,	0.206226,	0.707471)
#
#
# aLTER TABLE temp ADD five varchar(10)
#
# update temp
# set five='one' where idx=1
#
# update temp
# set five='one' where idx=2
# --,('two'),('three'),('four'),('three')
#
# select * from temp

# %%
df2[df2['five'].isin(['two','four'])]
# Out:
#                  one       two     three      four  ID  five
# dates
# 2014-11-03  1.056507 -0.804262  0.762899  1.005693   3   two
# 2014-11-05  1.069675  0.149181 -0.012881 -0.503559   5  four

# %%
sqldf("select * from df2 where five in ('two','four')")
# Out:
#                         dates       one       two     three      four  ID  \
# 0  2014-11-03 00:00:00.000000  1.056507 -0.804262  0.762899  1.005693   3
# 1  2014-11-05 00:00:00.000000  1.069675  0.149181 -0.012881 -0.503559   5
#
#    five
# 0   two
# 1  four

# %% [markdown]
# ## Setting/updating
# Setting a new column automatically aligns the data by the indexes

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20141101', periods=6))
s1
# Out:
# 2014-11-01    1
# 2014-11-02    2
# 2014-11-03    3
# 2014-11-04    4
# 2014-11-05    5
# 2014-11-06    6
# Freq: D, dtype: int64

# %%
df['six'] = s1
df
# Out:
#                  one       two     three      four  six  ID
# dates
# 2014-11-01  0.000000  1.859800  1.050713  0.942618    1   1
# 2014-11-02  0.765643  0.735878  1.589891 -0.531448    2   2
# 2014-11-03  0.758041 -1.034167  1.100249  0.678100    3   3
# 2014-11-04  0.539934  0.730257 -0.858822 -1.133150    4   4
# 2014-11-05  0.606519  0.017875  2.958902  0.337166    5   5
# 2014-11-06  0.187048 -1.796126 -1.140436  0.856097    6   6

# %% [markdown]
# Setting values by label:

# %%
df.at[dates[0],'one'] = 0
df
# Out:
#                  one       two     three      four  six
# dates
# 2014-11-01  0.000000  1.859800  1.050713  0.942618    1
# 2014-11-02  0.765643  0.735878  1.589891 -0.531448    2
# 2014-11-03  0.758041 -1.034167  1.100249  0.678100    3
# 2014-11-04  0.539934  0.730257 -0.858822 -1.133150    4
# 2014-11-05  0.606519  0.017875  2.958902  0.337166    5
# 2014-11-06  0.187048 -1.796126 -1.140436  0.856097    6

# %% [markdown]
# Setting values by position:

# %%
df.iat[0,1] = 0
df
# Out:
#                  one       two     three      four  ID  six
# dates
# 2014-11-01  0.000000  0.000000  1.617015 -1.465993   1    1
# 2014-11-02  1.279714 -0.264422  0.206226  0.707471   2    2
# 2014-11-03  1.056507 -0.804262  0.762899  1.005693   3    3
# 2014-11-04  1.199555  1.033413 -0.450919  0.113587   4    4
# 2014-11-05  1.069675  0.149181 -0.012881 -0.503559   5    5
# 2014-11-06  0.094150 -0.387608  0.761176  1.658888   6    6

# %%
df.loc[:,'four'] = np.array([5] * len(df))
df
# Out:
#                  one       two     three  four  six  ID
# dates
# 2014-11-01  0.000000  1.859800  1.050713     5    1   1
# 2014-11-02  0.765643  0.735878  1.589891     5    2   2
# 2014-11-03  0.758041 -1.034167  1.100249     5    3   3
# 2014-11-04  0.539934  0.730257 -0.858822     5    4   4
# 2014-11-05  0.606519  0.017875  2.958902     5    5   5
# 2014-11-06  0.187048 -1.796126 -1.140436     5    6   6

# %% [markdown]
# A where operation with setting.

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                  one       two     three  four  six  ID
# dates
# 2014-11-01  0.000000 -1.859800 -1.050713    -5   -1  -1
# 2014-11-02 -0.765643 -0.735878 -1.589891    -5   -2  -2
# 2014-11-03 -0.758041 -1.034167 -1.100249    -5   -3  -3
# 2014-11-04 -0.539934 -0.730257 -0.858822    -5   -4  -4
# 2014-11-05 -0.606519 -0.017875 -2.958902    -5   -5  -5
# 2014-11-06 -0.187048 -1.796126 -1.140436    -5   -6  -6

# %% [markdown]
# ## Missing Data
# pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations. See the
#
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data.

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df1
# Out:
#                  one       two     three  four  six  ID    E
# dates
# 2014-11-01  0.000000  1.859800  1.050713     5    1   1  1.0
# 2014-11-02  0.765643  0.735878  1.589891     5    2   2  1.0
# 2014-11-03  0.758041 -1.034167  1.100249     5    3   3  NaN
# 2014-11-04  0.539934  0.730257 -0.858822     5    4   4  NaN

# %% [markdown]
# To drop any rows that have missing data:

# %%
df1.dropna(how='any')
# Out:
#                  one       two     three  four  six  ID    E
# dates
# 2014-11-01  0.000000  1.859800  1.050713     5    1   1  1.0
# 2014-11-02  0.765643  0.735878  1.589891     5    2   2  1.0

# %%
sqldf('select * from df1 where E is not null')
# Out:
#                         dates       one       two     three  four  six  ID  \
# 0  2014-11-01 00:00:00.000000  0.000000  1.859800  1.050713     5    1   1
# 1  2014-11-02 00:00:00.000000  0.765643  0.735878  1.589891     5    2   2
#
#      E
# 0  1.0
# 1  1.0

# %% [markdown]
# Filling missing data:

# %%
df1.fillna(value=5)
# Out:
#                  one       two     three  four  six  ID    E
# dates
# 2014-11-01  0.000000  1.859800  1.050713     5    1   1  1.0
# 2014-11-02  0.765643  0.735878  1.589891     5    2   2  1.0
# 2014-11-03  0.758041 -1.034167  1.100249     5    3   3  5.0
# 2014-11-04  0.539934  0.730257 -0.858822     5    4   4  5.0

# %%
sqldf('select *, ifnull(E,5) as E from df1')
# Out:
#                         dates       one       two     three  four  six  ID  \
# 0  2014-11-01 00:00:00.000000  0.000000  1.859800  1.050713     5    1   1
# 1  2014-11-02 00:00:00.000000  0.765643  0.735878  1.589891     5    2   2
# 2  2014-11-03 00:00:00.000000  0.758041 -1.034167  1.100249     5    3   3
# 3  2014-11-04 00:00:00.000000  0.539934  0.730257 -0.858822     5    4   4
#
#      E    E
# 0  1.0  1.0
# 1  1.0  1.0
# 2  NaN  5.0
# 3  NaN  5.0

# %% [markdown]
# ## Operations

# %% [markdown]
# ### Stats
# Operations in general *exclude* missing data.
#
# Performing a descriptive statistic:

# %%
df
# Out:
#                  one       two     three  four  six  ID
# dates
# 2014-11-01  0.000000  1.859800  1.050713     5    1   1
# 2014-11-02  0.765643  0.735878  1.589891     5    2   2
# 2014-11-03  0.758041 -1.034167  1.100249     5    3   3
# 2014-11-04  0.539934  0.730257 -0.858822     5    4   4
# 2014-11-05  0.606519  0.017875  2.958902     5    5   5
# 2014-11-06  0.187048 -1.796126 -1.140436     5    6   6

# %%
df.mean()
# Out:
# one      0.476198
# two      0.085586
# three    0.783416
# four     5.000000
# six      3.500000
# ID       3.500000
# dtype: float64

# %%
sqldf('select avg(one),avg(two),avg(three),avg(four) from df')
# Out:
#    avg(one)  avg(two)  avg(three)  avg(four)
# 0  0.476198  0.085586    0.783416        5.0

# %% [markdown]
# Same operation on the other axis:

# %%
df.mean(1)
# Out:
# dates
# 2014-11-01    1.651752
# 2014-11-02    2.015235
# 2014-11-03    1.970687
# 2014-11-04    2.235228
# 2014-11-05    3.097216
# 2014-11-06    2.375081
# Freq: D, dtype: float64

# %% [markdown]
# Operating with objects that have different dimensionality and need alignment. In addition, pandas automatically broadcasts along the specified dimension. The following code also shifts the data vertically, leaving NaN values in the unoccupied spaces

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)
s
# Out:
# dates
# 2014-11-01    NaN
# 2014-11-02    NaN
# 2014-11-03    1.0
# 2014-11-04    3.0
# 2014-11-05    5.0
# 2014-11-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                  one       two     three  four  six   ID
# dates
# 2014-11-01       NaN       NaN       NaN   NaN  NaN  NaN
# 2014-11-02       NaN       NaN       NaN   NaN  NaN  NaN
# 2014-11-03 -0.241959 -2.034167  0.100249   4.0  2.0  2.0
# 2014-11-04 -2.460066 -2.269743 -3.858822   2.0  1.0  1.0
# 2014-11-05 -4.393481 -4.982125 -2.041098   0.0  0.0  0.0
# 2014-11-06       NaN       NaN       NaN   NaN  NaN  NaN

# %% [markdown]
# ### Apply
# Applying functions to the data

# %%
df
# Out:
#                  one       two     three  four  six  ID
# dates
# 2014-11-01  0.000000  1.859800  1.050713     5    1   1
# 2014-11-02  0.765643  0.735878  1.589891     5    2   2
# 2014-11-03  0.758041 -1.034167  1.100249     5    3   3
# 2014-11-04  0.539934  0.730257 -0.858822     5    4   4
# 2014-11-05  0.606519  0.017875  2.958902     5    5   5
# 2014-11-06  0.187048 -1.796126 -1.140436     5    6   6

# %%
df.apply(np.cumsum)
# Out:
#                  one       two     three  four  six  ID
# dates
# 2014-11-01  0.000000  1.859800  1.050713     5    1   1
# 2014-11-02  0.765643  2.595678  2.640604    10    3   3
# 2014-11-03  1.523684  1.561511  3.740853    15    6   6
# 2014-11-04  2.063618  2.291767  2.882031    20   10  10
# 2014-11-05  2.670137  2.309642  5.840934    25   15  15
# 2014-11-06  2.857185  0.513516  4.700498    30   21  21

# %% [markdown]
# ### String Methods
# Series is equipped with a set of string processing methods in the str attribute that make it easy to operate on each element of the array, as in the code snippet below. Note that pattern-matching in str generally uses [regular expressions]

# %%
df_s = pd.DataFrame(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])
df_s
# Out:
#       0
# 0     A
# 1     B
# 2     C
# 3  Aaba
# 4  Baca
# 5   NaN
# 6  CABA
# 7   dog
# 8   cat

# %%
df_s[0].str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# Name: 0, dtype: object

# %%
sqldf('select lower("0") from df_s')
# Out:
#   lower("0")
# 0          a
# 1          b
# 2          c
# 3       aaba
# 4       baca
# 5       None
# 6       caba
# 7        dog
# 8        cat

# %% [markdown]
# # Merge
# ### Concat
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -0.613050  0.206320 -0.471115 -1.007161
# 1 -0.033458 -0.654743 -0.206576 -0.234649
# 2 -0.301230  1.387636  0.746491  0.571956
# 3 -0.225315  0.012642  0.183437  1.551254
# 4 -2.056905 -0.588833  0.100110  0.767569
# 5  1.504868  1.475298  1.494610  1.525058
# 6  0.545204  0.009317 -0.822373 -1.544509
# 7 -0.192297 -0.183070 -0.045385 -1.053045
# 8  0.816033  0.337298  0.066676 -0.300874
# 9  1.046825 -1.676630 -0.893203  0.261171

# %%
#break it into pieces:
pieces = [df[:3], df[3:7], df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0 -0.613050  0.206320 -0.471115 -1.007161
#  1 -0.033458 -0.654743 -0.206576 -0.234649
#  2 -0.301230  1.387636  0.746491  0.571956,
#            0         1         2         3
#  3 -0.225315  0.012642  0.183437  1.551254
#  4 -2.056905 -0.588833  0.100110  0.767569
#  5  1.504868  1.475298  1.494610  1.525058
#  6  0.545204  0.009317 -0.822373 -1.544509,
#            0         1         2         3
#  7 -0.192297 -0.183070 -0.045385 -1.053045
#  8  0.816033  0.337298  0.066676 -0.300874
#  9  1.046825 -1.676630 -0.893203  0.261171]

# %%
# pd.concat(pieces,axis=1)
pd.concat(pieces,axis=0)
# Out:
#           0         1         2         3         0         1         2  \
# 0 -0.613050  0.206320 -0.471115 -1.007161       NaN       NaN       NaN
# 1 -0.033458 -0.654743 -0.206576 -0.234649       NaN       NaN       NaN
# 2 -0.301230  1.387636  0.746491  0.571956       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN -0.225315  0.012642  0.183437
# 4       NaN       NaN       NaN       NaN -2.056905 -0.588833  0.100110
# 5       NaN       NaN       NaN       NaN  1.504868  1.475298  1.494610
# 6       NaN       NaN       NaN       NaN  0.545204  0.009317 -0.822373
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 9       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           3         0         1         2         3
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# ...

# %% [markdown]
# ### Join

# %% [markdown]
# SQL style merges.

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left,right,on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
sqldf('select a.key, lval,rval from left a join right b on a.key=b.key')

# %% [markdown]
# Another example that can be given is:

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
sqldf('select a.key, lval,rval from left a join right b on a.key=b.key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %% [markdown]
# ### Append
# Append rows to a dataframe.

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0 -1.676725 -0.132261 -0.288947 -0.417174
# 1  1.233036  0.570251  0.852912 -2.088036
# 2 -2.114706 -0.685012  0.106313  0.965553
# 3 -1.073914 -0.093638  0.007090 -0.024345
# 4  0.472392 -0.417793  1.059780  2.472569
# 5  1.980942 -0.856629  1.121374 -0.067506
# 6  0.324152 -0.150234  0.204487 -0.651032
# 7 -0.398281  3.088795 -0.476628 -0.741581

# %%
s = df.iloc[3]
s
# Out:
# A   -1.073914
# B   -0.093638
# C    0.007090
# D   -0.024345
# Name: 3, dtype: float64

# %%
df.append(s,ignore_index=True)
# Out:
#           A         B         C         D
# 0 -1.676725 -0.132261 -0.288947 -0.417174
# 1  1.233036  0.570251  0.852912 -2.088036
# 2 -2.114706 -0.685012  0.106313  0.965553
# 3 -1.073914 -0.093638  0.007090 -0.024345
# 4  0.472392 -0.417793  1.059780  2.472569
# 5  1.980942 -0.856629  1.121374 -0.067506
# 6  0.324152 -0.150234  0.204487 -0.651032
# 7 -0.398281  3.088795 -0.476628 -0.741581
# 8 -1.073914 -0.093638  0.007090 -0.024345

# %%
s=pd.DataFrame(df.iloc[3]).T
sqldf('select * from df union all select * from s')
sqldf('select * from df union select * from s')
# Out:
#           A         B         C         D
# 0 -1.676725 -0.132261 -0.288947 -0.417174
# 1  1.233036  0.570251  0.852912 -2.088036
# 2 -2.114706 -0.685012  0.106313  0.965553
# 3 -1.073914 -0.093638  0.007090 -0.024345
# 4  0.472392 -0.417793  1.059780  2.472569
# 5  1.980942 -0.856629  1.121374 -0.067506
# 6  0.324152 -0.150234  0.204487 -0.651032
# 7 -0.398281  3.088795 -0.476628 -0.741581
# 8 -1.073914 -0.093638  0.007090 -0.024345

# %% [markdown]
# # Grouping
# By “group by” we are referring to a process involving one or more of the following steps
#
# Splitting the data into groups based on some criteria
# Applying a function to each group independently
# Combining the results into a data structure

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
   ....:                           'foo', 'bar', 'foo', 'foo'],
   ....:                    'B' : ['one', 'one', 'two', 'three',
   ....:                           'two', 'two', 'one', 'three'],
   ....:                    'C' : np.random.randn(8),
   ....:                    'D' : np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one -1.504493  0.902376
# 1  bar    one  1.343919  1.650106
# 2  foo    two -1.702405  1.953770
# 3  bar  three  1.429505 -0.779824
# 4  foo    two -0.666313 -0.882545
# 5  bar    two -0.050544 -1.331401
# 6  foo    one -1.239700 -0.382242
# 7  foo  three  1.023162  1.460373

# %% [markdown]
# Grouping and then applying a function sum to the resulting groups.

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  2.722879 -0.461120
# foo -4.089750  3.051732

# %%
sqldf('select A,sum(C) as C, sum(D) as D from df group by A')
# Out:
#      A         C         D
# 0  bar  2.722879 -0.461120
# 1  foo -4.089750  3.051732

# %%
df.groupby('A').mean()
# Out:
#             C         D
# A
# bar  0.172017 -0.908110
# foo -0.257651 -0.347607

# %% [markdown]
# Grouping by multiple columns forms a hierarchical index, which we then apply the function.

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    1.343919  1.650106
#     three  1.429505 -0.779824
#     two   -0.050544 -1.331401
# foo one   -2.744193  0.520134
#     three  1.023162  1.460373
#     two   -2.368718  1.071225

# %%
sqldf('select A,B,sum(C) as C, sum(D) as D from df group by A,B')
# Out:
#      A      B         C         D
# 0  bar    one  1.343919  1.650106
# 1  bar  three  1.429505 -0.779824
# 2  bar    two -0.050544 -1.331401
# 3  foo    one -2.744193  0.520134
# 4  foo  three  1.023162  1.460373
# 5  foo    two -2.368718  1.071225

# %% [markdown]
# # Reshaping
#
#
# ### Stack

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
   ....:                      'foo', 'foo', 'qux', 'qux'],
   ....:                     ['one', 'two', 'one', 'two',
   ....:                      'one', 'two', 'one', 'two']]))
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df
# Out:
#                      A         B
# first second
# bar   one     0.416633 -0.504833
#       two     1.030611  0.068650
# baz   one    -0.264914 -0.131666
#       two    -0.036743 -0.344510
# foo   one    -0.164668  0.367552
#       two    -0.136837  0.004807
# qux   one    -0.363677  0.424450
#       two    -1.296324 -0.314288

# %% [markdown]
# The [stack()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.stack.html#pandas.DataFrame.stack) method “compresses” a level in the DataFrame’s columns.

# %%
stacked = df.stack()
stacked
# Out:
# first  second
# bar    one     A    0.416633
#                B   -0.504833
#        two     A    1.030611
#                B    0.068650
# baz    one     A   -0.264914
#                B   -0.131666
#        two     A   -0.036743
#                B   -0.344510
# foo    one     A   -0.164668
#                B    0.367552
#        two     A   -0.136837
#                B    0.004807
# qux    one     A   -0.363677
#                B    0.424450
#        two     A   -1.296324
#                B   -0.314288
# dtype: float64

# %% [markdown]
# With a “stacked” DataFrame or Series (having a MultiIndex as the index), the inverse operation of [stack()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.stack.html#pandas.DataFrame.stack) is [unstack()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.unstack.html#pandas.DataFrame.unstack), which by default unstacks the last level:

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.416633 -0.504833
#       two     1.030611  0.068650
# baz   one    -0.264914 -0.131666
#       two    -0.036743 -0.344510
# foo   one    -0.164668  0.367552
#       two    -0.136837  0.004807
# qux   one    -0.363677  0.424450
#       two    -1.296324 -0.314288

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.416633  1.030611
#       B -0.504833  0.068650
# baz   A -0.264914 -0.036743
#       B -0.131666 -0.344510
# foo   A -0.164668 -0.136837
#       B  0.367552  0.004807
# qux   A -0.363677 -1.296324
#       B  0.424450 -0.314288

# %%
stacked.unstack(0)
# Out:
# first          bar       baz       foo       qux
# second
# one    A  0.416633 -0.264914 -0.164668 -0.363677
#        B -0.504833 -0.131666  0.367552  0.424450
# two    A  1.030611 -0.036743 -0.136837 -1.296324
#        B  0.068650 -0.344510  0.004807 -0.314288

# %% [markdown]
# ### Pivot Tables

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
   .....:                    'B' : ['A', 'B', 'C'] * 4,
   .....:                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
   .....:                    'D' : np.random.randn(12),
   .....:                    'E' : np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -1.940031  0.059795
# 1     one  B  foo  1.027867  2.292730
# 2     two  C  foo  0.385820 -1.910379
# 3   three  A  bar  1.934140  0.388194
# 4     one  B  bar -1.127982 -0.019367
# 5     one  C  bar -1.086721 -1.538660
# 6     two  A  foo -0.633646 -1.452280
# 7   three  B  foo  0.044460 -0.433347
# 8     one  C  foo -0.198853  1.343433
# 9     one  A  bar -0.038107 -0.250330
# 10    two  B  bar -0.056841 -2.057160
# 11  three  C  bar  0.110814  0.667232

# %% [markdown]
# We can produce pivot tables from this data very easily:

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.038107 -1.940031
#       B -1.127982  1.027867
#       C -1.086721 -0.198853
# three A  1.934140       NaN
#       B       NaN  0.044460
#       C  0.110814       NaN
# two   A       NaN -0.633646
#       B -0.056841       NaN
#       C       NaN  0.385820

# %% [markdown]
# # Categoricals
# pandas can include categorical data in a DataFrame.

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %% [markdown]
# Convert the raw grades to a categorical data type:

# %%
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %% [markdown]
# Rename the categories to more meaningful names (assigning to Series.cat.categories is inplace!)

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %% [markdown]
# Reorder the categories and simultaneously add the missing categories (methods under Series .cat return a new Series per default).

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %% [raw]
# Sorting is per order in the categories, not lexical order.

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %% [markdown]
# Grouping by a categorical column shows also empty categories.

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# # Plotting

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# On DataFrame, plot() is a convenience to plot all of the columns with labels:

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
   .....:                   columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
df.plot();

# %% [markdown]
# # Getting Data In/Out
# ### CSV

# %%
df=pd.read_csv('C:/Business_Data_Analysis/data/HR_Employee_Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.to_csv('test.csv')

# %% [markdown]
# ### Excel
#
#
# Writing to an excel file:

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %% [markdown]
# Reading from an excel file:

# %%
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])

# %% [markdown]
# # Error Handling
# If you are trying an operation and you see an exception like:

# %%
if pd.Series([False, True, False]):
    print("I was true")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_38116/2648304181.py in <module>
# ----> 1 if pd.Series([False, True, False]):
#       2     print("I was true")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import traceback
try:
#     print("Hello")
    if pd.Series([False, True, False]):
        print("I was true")
except Exception as e:
    print("Something went wrong")
#     print(traceback.format_exc())
    print(e) 
else:
    print("Nothing went wrong")
# Out:
# I was true
# Nothing went wrong

# %% [markdown]
# # Function

# %%
#syntax
def function_name(parameters):
	"""docstring"""
	statement(s)

# %%
def greet(name):
    """
    This function greets to
    the person passed in as
    a parameter
    """
    print("Hello, " + name + ". Good morning!")

# %%
def absolute_value(num):
    """This function returns the absolute
    value of the entered number"""

    if num >= 0:
        return num
    else:
        return -num


print(absolute_value(2))

print(absolute_value(-4))
