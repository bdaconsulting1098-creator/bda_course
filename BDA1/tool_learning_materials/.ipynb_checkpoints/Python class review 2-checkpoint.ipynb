# %% [markdown]
# ![image-7.png](attachment:image-7.png)![image-9.png](attachment:image-9.png)![image-10.png](attachment:image-10.png)

# %%
#import modules
import pandas as pd
import os
path=os.environ['USERPROFILE']+r'/OneDrive/BDA1/'

# %% [markdown]
# # 1 - Input

# %% [markdown]
# ## csv

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\bdaon\OneDrive\BDA1\data\Customer.csv")
df
# Out:
#        CustomerKey Customer ID          Customer        City   State-Province  \
# 0            11024  AW00011024       Russell Xie     Concord       California
# 1            11081  AW00011081    Savannah Baker     Concord       California
# 2            11160  AW00011160      Maurice Tang     Concord       California
# 3            11161  AW00011161        Emily Wood     Concord       California
# 4            11184  AW00011184  Meghan Hernandez     Concord       California
# ...            ...         ...               ...         ...              ...
# 18480        29083  AW00029083     Toni Sullivan  Matraville  New South Wales
# 18481        29098  AW00029098        Jimmy Gill  Matraville  New South Wales
# 18482        29305  AW00029305      Beth Alvarez  Matraville  New South Wales
# 18483        29316  AW00029316        Max Romero  Matraville  New South Wales
# 18484        29465  AW00029465          Roy Gill  Matraville  New South Wales
#
#       Country-Region Postal Code
# 0      United States       94519
# 1      United States       94519
# 2      United States       94519
# 3      United States       94519
# 4      United States       94519
# ...              ...         ...
# 18480      Australia        2036
# 18481      Australia        2036
# 18482      Australia        2036
# 18483      Australia        2036
# 18484      Australia        2036
#
# [18485 rows x 7 columns]

# %%
#python

csv_file = path+r"\data\tips.csv"

#dataframe
df_from_csv = pd.read_csv(csv_file)

df_from_csv.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_from_csv.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
#sql
'''BULK INSERT credit_train
    FROM 'C:\Business_Data_Analysis\data\credit_train.csv'
    WITH
    (
    FIRSTROW = 2,
    FIELDTERMINATOR = ',',  --CSV field delimiter
    ROWTERMINATOR = '\n',   --Use to shift the control to next row
    ERRORFILE = 'C:\CSVDATA\SchoolsErrorRows.csv',
    TABLOCK
    )'''

# %%
#SAS
proc import datafile='tips.csv' dbms=csv out=tips replace;
    getnames=yes;
run;

#dataset
# Out:
#   File "C:\Users\bdaon\AppData\Local\Temp/ipykernel_22680/3969169645.py", line 2
#     proc import datafile='tips.csv' dbms=csv out=tips replace;
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## text file

# %%
#python
mydata = pd.read_table("C:\\Desktop\\example2.txt")
mydata = pd.read_csv("C:\\Desktop\\example2.txt", sep ="\t")

# %% [markdown]
# ## excel

# %%
#python
excel_file = path+r"\data\AdventureWorks Sales.xlsx"
df_from_excel = pd.read_excel(excel_file)
df_from_excel.head()
# Out:
#     Channel  SalesOrderLineKey Sales Order Sales Order Line
# 0  Reseller           43659001     SO43659      SO43659 - 1
# 1  Reseller           43659002     SO43659      SO43659 - 2
# 2  Reseller           43659003     SO43659      SO43659 - 3
# 3  Reseller           43659004     SO43659      SO43659 - 4
# 4  Reseller           43659005     SO43659      SO43659 - 5

# %% [markdown]
# ## SAS

# %%
df_from_sas = pd.read_sas(path+r"\data\life.sas7bdat")
df_from_sas.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22904/683833089.py in <module>
# ----> 1 df_from_sas = pd.read_sas(path+r"\data\life.sas7bdat")
#       2 df_from_sas.head()
#
# ~\anaconda3\lib\site-packages\pandas\io\sas\sasreader.py in read_sas(filepath_or_buffer, format, index, encoding, chunksize, iterator)
#     146         from pandas.io.sas.sas7bdat import SAS7BDATReader
#     147
# --> 148         reader = SAS7BDATReader(
#     149             filepath_or_buffer,
#     150             index=index,
#
# ~\anaconda3\lib\site-packages\pandas\io\sas\sas7bdat.py in __init__(self, path_or_buf, index, convert_dates, blank_missing, chunksize, encoding, convert_text, convert_header_text)
#     195         self._current_row_in_file_index = 0
#     196
# --> 197         self.handles = get_handle(path_or_buf, "rb", is_text=False)
#     198
#     199         self._path_or_buf = cast(IO[Any], self.handles.handle)
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\bdaon/OneDrive/BDA2/\\data\\life.sas7bdat'

# %% [markdown]
# ## data structure: list,Dict, Array

# %%
list [1,2,'erw']   dictionary {'a':1, 'b':3} 
array([[-0.48479077, -0.51541263,  1.02174233,  0.2940478 ],
       [ 0.00671131, -1.73351438,  1.50997736,  1.48942854],
       [ 0.64740529,  0.1355594 , -1.04325823,  0.36031536],
       [ 1.37617244, -2.41264344,  1.18923317, -0.35403184],
       [ 0.37270292, -0.17271254, -1.03702008,  0.3676547 ],
       [ 0.49852348,  0.85627004, -0.84514847,  0.63807985]])
# Out:
#   File "C:\Users\bdaon\AppData\Local\Temp/ipykernel_11764/1776399175.py", line 1
#     list [1,2,'erw']   dictionary {'a':1, 'b':3}
#                        ^
# SyntaxError: invalid syntax

# %%
#sql 
CREATE TABLE table_name (
    column1 datatype,
    column2 datatype,
    column3 datatype,
   ....
);

INSERT INTO table_name (column1, column2, column3, ...)
VALUES (value1, value2, value3, ...);

# %%
#python
import numpy as np
df2 = pd.DataFrame({ 'A' : 1.,
                        'B' : pd.Timestamp('20130102'),
                        'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                        'D' : np.array([3] * 4,dtype='int32'),
                        'E' : pd.Categorical(["test","train","test","train"]),
                        'F' : 'foo' })
   
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
#SAS
data df;
    input x y;
    datalines;
    1 2
    3 4
    5 6
    ;
run;

# %% [markdown]
# ## database

# %%
import pyodbc
import urllib
import sqlalchemy

params_datahub = urllib.parse.quote_plus("DRIVER={SQL Server Native Client 11.0};"
                                 "SERVER=localhost\SQLEXPRESS;"
                                 "DATABASE=datahub;"
                                 "UID=sa;"
                                 "PWD=user1")

engine_datahub = sqlalchemy.create_engine("mssql+pyodbc:///?odbc_connect={}".format(params_datahub))


df_sales_p=pd.read_sql_table('tips',engine_datahub)


df_sales_p.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size bucket
# 0       16.99  1.01  Female     No  Sun  Dinner     2   high
# 1       10.34  1.66    Male     No  Sun  Dinner     3   high
# 2       21.01  3.50    Male     No  Sun  Dinner     3   high
# 3       23.68  3.31    Male     No  Sun  Dinner     2   high
# 4       24.59  3.61  Female     No  Sun  Dinner     4   high

# %% [markdown]
# ## internet

# %%
import requests
response = requests.get("http://api.open-notify.org/astros.json")
print(response.status_code)
print(response.json())
res = pd.DataFrame(response.json()["people"])
res.head()
# Out:
# 200
# {'message': 'success', 'number': 10, 'people': [{'craft': 'ISS', 'name': 'Sergey Prokopyev'}, {'craft': 'ISS', 'name': 'Dmitry Petelin'}, {'craft': 'ISS', 'name': 'Frank Rubio'}, {'craft': 'Shenzhou 15', 'name': 'Fei Junlong'}, {'craft': 'Shenzhou 15', 'name': 'Deng Qingming'}, {'craft': 'Shenzhou 15', 'name': 'Zhang Lu'}, {'craft': 'ISS', 'name': 'Stephen Bowen'}, {'craft': 'ISS', 'name': 'Warren Hoburg'}, {'craft': 'ISS', 'name': 'Sultan Alneyadi'}, {'craft': 'ISS', 'name': 'Andrey Fedyaev'}]}
#          craft              name
# 0          ISS  Sergey Prokopyev
# 1          ISS    Dmitry Petelin
# 2          ISS       Frank Rubio
# 3  Shenzhou 15       Fei Junlong
# 4  Shenzhou 15     Deng Qingming

# %% [markdown]
# ## API

# %%
# %pip install pandas_datareader
from pandas_datareader import data
import datetime as dt
zm = data.DataReader(
    "BAC",
    start='2022-9-10',
    end=dt.datetime.today(),
    data_source='yahoo'
).reset_index()
zm.head()
# Out:
#         Date       High        Low       Open      Close    Volume  Adj Close
# 0 2022-09-12  35.630001  35.029999  35.200001  35.270000  30534000  35.270000
# 1 2022-09-13  34.720001  33.810001  34.580002  34.000000  40959600  34.000000
# 2 2022-09-14  34.419998  33.540001  34.200001  33.869999  32004400  33.869999
# 3 2022-09-15  34.900002  33.700001  33.790001  34.509998  44863300  34.509998
# 4 2022-09-16  34.230000  33.660000  34.189999  34.119999  54235200  34.119999

# %%
# %pip install selenium
# %pip install webdriver-manager
import requests

def get_news(country, api_key='890603a55bfa47048e4490069ebee18c'):
  url = f'https://newsapi.org/v2/top-headlines?country={country}&apiKey={api_key}'
  r = requests.get(url)
  content = r.json()
  articles = content['articles']
  results = []
  for article in articles:
    results.append(f"TITLE\n'{article['title']}, '\nDESCRIPTION\n', {article['description']}")
  return results

display(get_news(country='us'))
# Out:
# ["TITLE\n'Europe holds its breath as Italy prepares to vote in far-right leader - The Guardian, '\nDESCRIPTION\n', Coalition led by Giorgia Meloni would be country’s most radical government since Mussolini",
#  "TITLE\n'Fantasy: Week 3 Rankings (Sunday Update) - theScore, '\nDESCRIPTION\n', Find positional rankings, additional analysis, and subscribe to push notifications in the NFL Fantasy News section.theScore's Justin Boone was first overall in FantasyPros' Most Accurate Expert Competition in 2019 and finished among the top seven each of his …",
#  "TITLE\n'NASA stands down from Tuesday launch for Artemis I, holding off rollback decision - Orlando Sentinel, '\nDESCRIPTION\n', With the approaching threat of what is forecast to be Hurricane Ian, NASA finally threw in the towel Saturday for a launch attempt Tuesday of its Artemis I mission to the moon from Kennedy Space Center. A decision to roll back could come late Sunday.",
#  "TITLE\n'Post Malone cancels Boston concert after returning to the hospital - CNN, '\nDESCRIPTION\n', It's been a rough few weeks for Post Malone.",
#  "TITLE\n'Tropical Storm Ian growing, but 'significant uncertainty' remains with Florida track - Orlando Sentinel, '\nDESCRIPTION\n', There are still significant differences regarding the exact track of the storm, especially after 72 hours,” the NHC cautioned on Sunday",
#  'TITLE\n\'Zelenskyy on Putin\'s threat of nuclear weapons: \'I don\'t think he\'s bluffing\' - CNBC, \'\nDESCRIPTION\n\', Ukrainian President Volodymyr Zelenskyy said Russia\'s threat of nuclear weapons use "could be a reality," in an interview with CBS\' "Face the Nation" on Sunday.',
#  "TITLE\n'Russian anti-war protests highlight trouble for Putin's war in Ukraine - USA TODAY, '\nDESCRIPTION\n', Massive anti-war protests are a sign President Vladimir Putin has failed to rally the Russian people behind his war in Ukraine, analysts say.",
#  "TITLE\n'Inside the Fetterman Campaign's Bizarre Bromance - The Daily Beast, '\nDESCRIPTION\n', “[T]hey’re playing off of each other’s strengths,” former chair of the PA Democrats T.J. Rooney said, noting Fetterman and Shapiro are “not cut from the same cloth, remotely.”",
#  'TITLE\n\'Alec And Hilaria Baldwin Just Had Their Seventh Kid, And I Think I Need To Lie Down Over The Name - BuzzFeed, \'\nDESCRIPTION\n\', "Her Baldwinito siblings are spending the day bonding and welcoming her into our home."',
#  "TITLE\n'North Korea fires ballistic missile ahead of U.S. VP Harris visit - Reuters, '\nDESCRIPTION\n', North Korea fired a ballistic missile towards the sea off its east coast on Sunday, ahead of planned military drills by South Korean and U.S. forces involving an aircraft carrier and a visit to the region by U.S. Vice President Kamala Harris.",
#  "TITLE\n'NFL Upright Turns Field Goal Drama Into ‘Doink’ in Arkansas Loss to Texas A&M - Sports Illustrated, '\nDESCRIPTION\n', At JerryWorld, the Razorbacks saw a late field goal bounce off the top of the upright. But what would’ve happened in a college stadium?",
#  "TITLE\n'Kim Kardashian oozes glamour after the D&G show with kids Saint, Chicago and Psalm during MFW - Daily Mail, '\nDESCRIPTION\n', The reality star, 42, oozed Hollywood glamour on Saturday as she left the Dolce & Gabbana SS23 show during Milan Fashion Week with Saint, six and Chicago, four and three-year-old Psalm.",
#  "TITLE\n'Pushing East of Kupyansk, Ukrainian Forces Expand Offensive - The Wall Street Journal, '\nDESCRIPTION\n', Securing the remaining Russian-held urban areas on the town’s eastern side would clear the way for Ukrainian forces to push into Luhansk, one of the regions that Moscow seeks to annex through snap referendums under way.",
#  "TITLE\n'NASA testing planetary defense by crashing spacecraft into an asteroid - The Washington Post, '\nDESCRIPTION\n', If everything goes as planned, and the laws of gravity and motion don’t change at the last minute, the asteroid collision will happen at exactly 7:14:23 EST.",
#  "TITLE\n'2022 NFL Week 3 Picks: Bills blow out Dolphins, Bengals and Texans pick up first wins - CBS Sports, '\nDESCRIPTION\n', All of Will Brinson's picks and best bets for Week 3 of the 2022 NFL season",
#  "TITLE\n'Liz Cheney says she will not remain a Republican if Donald Trump is GOP nominee in 2024 - CNN, '\nDESCRIPTION\n', Wyoming GOP Rep. Liz Cheney said at The Texas Tribune Festival Saturday that if former President Donald Trump becomes the Republican Party's nominee for president in 2024, she will not remain a Republican.",
#  "TITLE\n'Once nicknamed 'Murderapolis,' the city that became the center of the 'Defund the Police' movement is grappling with heightened violent crime - CNN, '\nDESCRIPTION\n', Marnette Gordon was doing laundry at home in Minneapolis one summer morning last year when a call came from her 36-year-old son.",
#  "TITLE\n'Horoscope for the Week of September 25, 2022, Weekly Horoscope - Cosmopolitan, '\nDESCRIPTION\n', Everything you need to know for the upcoming week.",
#  "TITLE\n'Biden's watchdog in the skies can't ground Air DeSantis - POLITICO, '\nDESCRIPTION\n', There’s probably little the Federal Aviation Administration can do to stop DeSantis from continuing the flights, people familiar with the agency’s legal authorities say.",
#  "TITLE\n'Why Trump allies are brushing off the New York AG lawsuit - The Hill, '\nDESCRIPTION\n', None"]

# %% [markdown]
# # 2- Processing

# %%
csv_file = path+r"\data\tips.csv"
tips = pd.read_csv(csv_file)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Select

# %%
#sql
'''SELECT total_bill, tip, smoker, time FROM tips;'''

# %%
#python
tips[["total_bill", "tip", "smoker", "time"]]
# Out:
#      total_bill   tip smoker    time
# 0         16.99  1.01     No  Dinner
# 1         10.34  1.66     No  Dinner
# 2         21.01  3.50     No  Dinner
# 3         23.68  3.31     No  Dinner
# 4         24.59  3.61     No  Dinner
# ..          ...   ...    ...     ...
# 239       29.03  5.92     No  Dinner
# 240       27.18  2.00    Yes  Dinner
# 241       22.67  2.00    Yes  Dinner
# 242       17.82  1.75     No  Dinner
# 243       18.78  3.00     No  Dinner
#
# [244 rows x 4 columns]

# %%
#SAS
data tips;
    set tips;
    keep total_bill tip smoker time;
run;

# %% [markdown]
# ### rename Column

# %%
#sql
select *,total_bill as total_bill_2 
from tips

# %%
#python
tips.rename(columns={"total_bill": "total_bill_2"})
# Out:
#      total_bill_2   tip     sex smoker   day    time  size
# 0           16.99  1.01  Female     No   Sun  Dinner     2
# 1           10.34  1.66    Male     No   Sun  Dinner     3
# 2           21.01  3.50    Male     No   Sun  Dinner     3
# 3           23.68  3.31    Male     No   Sun  Dinner     2
# 4           24.59  3.61  Female     No   Sun  Dinner     4
# ..            ...   ...     ...    ...   ...     ...   ...
# 239         29.03  5.92    Male     No   Sat  Dinner     3
# 240         27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         17.82  1.75    Male     No   Sat  Dinner     2
# 243         18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#sas
data tips;
    set tips;
    rename total_bill=total_bill_2;
run;

# %% [markdown]
# ### Add Column

# %%
#sql
'''SELECT *, tip/total_bill as tip_rate
FROM tips;'''

# %%
#python
tips['tip_rate']=tips["tip"] / tips["total_bill"]
# tips.assign(tip_rate=tips["tip"] / tips["total_bill"])

# %%
#SAS
data tips;
    set tips;
    tip_rate = tip/total_bill;
run;

# %% [markdown]
# ### Delete Column

# %%
#sql

# %%
#python
tips = tips.drop("tip_rate", axis=1)
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#sas
data tips;
    set tips;
    drop tip_rate;
run;

# %% [markdown]
# ## Sort

# %%
#sql
select * from tips
order by tip

# %%
#python
tips.sort_values(by='tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# ..          ...    ...     ...    ...   ...     ...   ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
#
# [244 rows x 7 columns]

# %%
#SAS
proc sort data=tips;
    by sex total_bill;
run;

# %% [markdown]
# ## Where

# %%
#sql
'''SELECT * FROM tips WHERE time = 'Dinner';'''

# %%
#python
tips[tips["time"] == "Dinner"]
# tips.query('time=="Dinner"')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
#sas
data tips;
    set tips;
    if time="Dinner";
run;

data tips;
    set tips;
    where time="Dinner";
    /* equivalent in this case - where happens before the
       DATA step begins and can also be used in PROC statements */
run;
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %% [markdown]
# ### i - and or

# %%
#sql
'''SELECT *
FROM tips
WHERE time = 'Dinner' AND tip > 5.00;'''

# %%
#python
tips[(tips["time"] == "Dinner") & (tips["tip"] > 5.00)]
# Out:
#      total_bill    tip     sex smoker  day    time  size
# 23        39.42   7.58    Male     No  Sat  Dinner     4
# 44        30.40   5.60    Male     No  Sun  Dinner     4
# 47        32.40   6.00    Male     No  Sun  Dinner     4
# 52        34.81   5.20  Female     No  Sun  Dinner     4
# 59        48.27   6.73    Male     No  Sat  Dinner     4
# 116       29.93   5.07    Male     No  Sun  Dinner     4
# 155       29.85   5.14  Female     No  Sun  Dinner     5
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3
# 172        7.25   5.15    Male    Yes  Sun  Dinner     2
# 181       23.33   5.65    Male    Yes  Sun  Dinner     2
# 183       23.17   6.50    Male    Yes  Sun  Dinner     4
# 211       25.89   5.16    Male    Yes  Sat  Dinner     4
# 212       48.33   9.00    Male     No  Sat  Dinner     4
# 214       28.17   6.50  Female    Yes  Sat  Dinner     3
# 239       29.03   5.92    Male     No  Sat  Dinner     3

# %%
#python
tips.query('time=="Dinner" and tip>5')
# Out:
#      total_bill    tip     sex smoker  day    time  size
# 23        39.42   7.58    Male     No  Sat  Dinner     4
# 44        30.40   5.60    Male     No  Sun  Dinner     4
# 47        32.40   6.00    Male     No  Sun  Dinner     4
# 52        34.81   5.20  Female     No  Sun  Dinner     4
# 59        48.27   6.73    Male     No  Sat  Dinner     4
# 116       29.93   5.07    Male     No  Sun  Dinner     4
# 155       29.85   5.14  Female     No  Sun  Dinner     5
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3
# 172        7.25   5.15    Male    Yes  Sun  Dinner     2
# 181       23.33   5.65    Male    Yes  Sun  Dinner     2
# 183       23.17   6.50    Male    Yes  Sun  Dinner     4
# 211       25.89   5.16    Male    Yes  Sat  Dinner     4
# 212       48.33   9.00    Male     No  Sat  Dinner     4
# 214       28.17   6.50  Female    Yes  Sat  Dinner     3
# 239       29.03   5.92    Male     No  Sat  Dinner     3

# %%
#sql
'''SELECT *
FROM tips
WHERE size >= 5 OR total_bill > 45;'''

# %%
#python
tips[(tips["size"] >= 5) | (tips["total_bill"] > 45)]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 125       29.80   4.20  Female     No  Thur   Lunch     6
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 143       27.05   5.00  Female     No  Thur   Lunch     6
# 155       29.85   5.14  Female     No   Sun  Dinner     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 185       20.69   5.00    Male     No   Sun  Dinner     5
# 187       30.46   2.00    Male    Yes   Sun  Dinner     5
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 216       28.15   3.00    Male    Yes   Sat  Dinner     5

# %%
#python
tips.query('size>=5 or total_bill>45')
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 125       29.80   4.20  Female     No  Thur   Lunch     6
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 143       27.05   5.00  Female     No  Thur   Lunch     6
# 155       29.85   5.14  Female     No   Sun  Dinner     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 185       20.69   5.00    Male     No   Sun  Dinner     5
# 187       30.46   2.00    Male    Yes   Sun  Dinner     5
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 216       28.15   3.00    Male    Yes   Sat  Dinner     5

# %%
#sas
data tips;
    set tips;
    if total_bill > 10;
run;

data tips;
    set tips;
    where total_bill > 10;
    /* equivalent in this case - where happens before the
       DATA step begins and can also be used in PROC statements */
run;

# %% [markdown]
# ### ii - null

# %%
import numpy as np

frame = pd.DataFrame(
    {"col1": ["A", "B", np.NaN, "C", "D"], "col2": ["F", np.NaN, "G", "H", "I"]}
)
frame
# Out:
#   col1 col2
# 0    A    F
# 1    B  NaN
# 2  NaN    G
# 3    C    H
# 4    D    I

# %%
#sql
'''SELECT *
FROM frame
WHERE col2 IS NULL;'''

# %%
#python
frame[frame["col2"].isna()]
# Out:
#   col1 col2
# 1    B  NaN

# %%
#sql
'''SELECT *
FROM frame
WHERE col1 IS NOT NULL;'''

# %%
#python
frame[frame["col1"].notna()]
# Out:
#   col1 col2
# 0    A    F
# 1    B  NaN
# 3    C    H
# 4    D    I

# %%
#sas

data df1;

input key $1 value 12.6;

datalines;
A  0.469112
B -0.282863
C -1.509059
D -1.135632
;

data df2;

input key $1 value 12.6;

datalines;
B  1.212112
D -0.173215
D  0.119209
E -1.044236
;

proc sort data=df1;
    by key;
run;

proc sort data=df2;
    by key;
run;

data left_join inner_join right_join outer_join;
    merge df1(in=a) df2(in=b);

    if a and b then output inner_join;
    if a then output left_join;
    if b then output right_join;
    if a or b then output outer_join;
run;


data outer_join_nulls;
    set outer_join;
    if value_x = .;
run;

data outer_join_no_nulls;
    set outer_join;
    if value_x ^= .;
run;

# %% [markdown]
# ## Case when

# %%
#sql
select *, 
case when total_bill<10 then 'low' else 'high' end as bucket
from tips

# %%
#python
tips["bucket"] = np.where(tips["total_bill"] < 10, "low", "high")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size bucket
# 0         16.99  2.02  Female     No   Sun  Dinner     2   high
# 1         10.34  3.32    Male     No   Sun  Dinner     3   high
# 2         21.01  3.50    Male     No   Sun  Dinner     3   high
# 3         23.68  3.31    Male     No   Sun  Dinner     2   high
# 4         24.59  3.61  Female     No   Sun  Dinner     4   high
# ..          ...   ...     ...    ...   ...     ...   ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3   high
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   high
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   high
# 242       17.82  3.50    Male     No   Sat  Dinner     2   high
# 243       18.78  3.00  Female     No  Thur  Dinner     2   high
#
# [243 rows x 8 columns]

# %%
#sas
data tips;
    set tips;
    format bucket $4.;

    if total_bill < 10 then bucket = 'low';
    else bucket = 'high';
run;

# %% [markdown]
# ## Date

# %%
#sql

select '2013-01-15' as date1, '2015-02-15' as date2 , year('2013-01-15') as date1_year, month('2015-02-15') as date2_month,

from tips

# %%
#python

tips["date1"] = pd.Timestamp("2013-01-15")

tips["date2"] = pd.Timestamp("2015-02-15")

tips["date1_year"] = tips["date1"].dt.year

tips["date2_month"] = tips["date2"].dt.month

tips["date1_next"] = tips["date1"] + pd.offsets.MonthBegin()

tips["months_between"] = tips["date2"].dt.to_period("M") - tips["date1"].dt.to_period("M")

tips[
    ["date1", "date2", "date1_year", "date2_month", "date1_next", "months_between"]
]
# Out:
#          date1      date2  date1_year  date2_month date1_next  \
# 0   2013-01-15 2015-02-15        2013            2 2013-02-01
# 1   2013-01-15 2015-02-15        2013            2 2013-02-01
# 2   2013-01-15 2015-02-15        2013            2 2013-02-01
# 3   2013-01-15 2015-02-15        2013            2 2013-02-01
# 4   2013-01-15 2015-02-15        2013            2 2013-02-01
# ..         ...        ...         ...          ...        ...
# 239 2013-01-15 2015-02-15        2013            2 2013-02-01
# 240 2013-01-15 2015-02-15        2013            2 2013-02-01
# 241 2013-01-15 2015-02-15        2013            2 2013-02-01
# 242 2013-01-15 2015-02-15        2013            2 2013-02-01
# 243 2013-01-15 2015-02-15        2013            2 2013-02-01
#
#        months_between
# 0    <25 * MonthEnds>
# 1    <25 * MonthEnds>
# 2    <25 * MonthEnds>
# 3    <25 * MonthEnds>
# 4    <25 * MonthEnds>
# ..                ...
# 239  <25 * MonthEnds>
# 240  <25 * MonthEnds>
# 241  <25 * MonthEnds>
# 242  <25 * MonthEnds>
# 243  <25 * MonthEnds>
#
# [243 rows x 6 columns]

# %%
#sas
data tips;
    set tips;
    format date1 date2 date1_next mmddyy10.;
    date1 = mdy(1, 15, 2013);
    date2 = mdy(2, 15, 2015);
    date1_year = year(date1);
    date2_month = month(date2);
    * shift date to beginning of next interval;
    date1_next = intnx('MONTH', date1, 1);
    * count intervals between dates;
    months_between = intck('MONTH', date1, date2);
run;

# %% [markdown]
# ## String processing

# %%
#PYTHON 
tips["time"].str.len()

tips["time"].str.rstrip().str.len()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11492/188302021.py in <module>
#       1 #PYTHON
# ----> 2 tips["time"].str.len()
#
# NameError: name 'tips' is not defined

# %%
#SAS

data _null_;
set tips;
a=LENGTHN(time);
b=LENGTHC(time);
put a=;
put b=;
run;

# %%
#python
tips["sex"].str.find("ale")
# Out:
# 0      3
# 1      1
# 2      1
# 3      1
# 4      3
#       ..
# 239    1
# 240    3
# 241    1
# 242    1
# 243    3
# Name: sex, Length: 244, dtype: int64

# %%
#sas
data _null_;
set tips;
a=FIND(sex,'ale');
put a=;
run;

# %%
#python
tips["sex"].str[0:1]
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
#SAS
data _null_;
set tips;
put(substr(sex,1,1));
run;

# %%
#python

firstlast = pd.DataFrame({"String": ["John Smith", "Jane Cook"]})

firstlast["First_Name"] = firstlast["String"].str.split(" ", expand=True)[0]

firstlast["Last_Name"] = firstlast["String"].str.rsplit(" ", expand=True)[1]

firstlast
# Out:
#        String First_Name Last_Name
# 0  John Smith       John     Smith
# 1   Jane Cook       Jane      Cook

# %%
#sas
data firstlast;
input String $60.;
First_Name = scan(string, 1);
Last_Name = scan(string, -1);*count from right;
datalines;
John Smith
Jane Cook
;
run;

# %%
#python
firstlast = pd.DataFrame({"string": ["John Smith", "Jane Cook"]})

firstlast["upper"] = firstlast["string"].str.upper()

firstlast["lower"] = firstlast["string"].str.lower()

firstlast["title"] = firstlast["string"].str.title()

firstlast
# Out:
#        string       upper       lower       title
# 0  John Smith  JOHN SMITH  john smith  John Smith
# 1   Jane Cook   JANE COOK   jane cook   Jane Cook

# %%
#sas
data firstlast;
input String $60.;
string_up = UPCASE(string);
string_low = LOWCASE(string);
string_prop = PROPCASE(string);
datalines2;
John Smith
Jane Cook
;;;
run;

# %% [markdown]
# ## Group

# %%
#sql
'''SELECT sex, count(*)
FROM tips
GROUP BY sex;'''

# %%
#python
tips.groupby("sex").size()
# Out:
# sex
# Female     87
# Male      157
# dtype: int64

# %%
#python
tips.groupby("sex")["total_bill"].count()
# Out:
# sex
# Female     87
# Male      157
# Name: total_bill, dtype: int64

# %%
#sql
'''SELECT day, AVG(tip), COUNT(*)
FROM tips
GROUP BY day;'''

# %%
#python
tips.groupby("day").agg({"tip": np.mean, "day": np.size})
# Out:
#            tip  day
# day
# Fri   2.734737   19
# Sat   2.993103   87
# Sun   3.255132   76
# Thur  2.771452   62

# %%
#sql
'''SELECT smoker, day, COUNT(*), AVG(tip)
FROM tips
GROUP BY smoker, day;'''

# %%
#python
tips.groupby(["smoker", "day"]).agg({"tip": [np.size, np.mean]})
# Out:
#              tip
#             size      mean
# smoker day
# No     Fri     4  2.812500
#        Sat    45  3.102889
#        Sun    57  3.167895
#        Thur   45  2.673778
# Yes    Fri    15  2.714000
#        Sat    42  2.875476
#        Sun    19  3.516842
#        Thur   17  3.030000

# %%
#SAS

proc summary data=tips nway;
    class sex smoker;
    var total_bill tip;
    output out=tips_summed sum=;
run;

or 

PROC SQL;
SELECT smoker, day, COUNT(*), AVG(tip)
FROM tips
GROUP BY smoker, day;
QUIT;

# %%
#sas
proc sort data=tips;
   by sex smoker;
run;

data tips_first;
    set tips;
    by sex smoker;
    if FIRST.sex or FIRST.smoker then output;
run;

# %% [markdown]
# ## join

# %%
df1 = pd.DataFrame({"key": ["A", "B", "C", "D"], "value1": np.random.randn(4)})

df2 = pd.DataFrame({"key": ["B", "D", "D", "E"], "value2": np.random.randn(4)})

# %%
#sql

'''SELECT *
FROM df1
INNER JOIN df2
  ON df1.key = df2.key;'''

# %%
#python
pd.merge(df1, df2, on="key")
# Out:
#   key    value1    value2
# 0   B -1.180994 -1.124198
# 1   D -2.098348  1.699971
# 2   D -2.098348 -0.990046

# %%
#sql
'''SELECT *
FROM df1
LEFT OUTER JOIN df2
  ON df1.key = df2.key;'''

# %%
#python
pd.merge(df1, df2, on="key", how="left")
# Out:
#   key    value1    value2
# 0   A -0.594641       NaN
# 1   B -1.180994 -1.124198
# 2   C  0.030645       NaN
# 3   D -2.098348  1.699971
# 4   D -2.098348 -0.990046

# %%
#sql
'''SELECT *
FROM df1
RIGHT OUTER JOIN df2
  ON df1.key = df2.key;'''

# %%
#python

pd.merge(df1, df2, on="key", how="right")

# %%
#SAS
proc sort data=df1;
    by key;
run;

proc sort data=df2;
    by key;
run;

data left_join inner_join right_join outer_join;
    merge df1(in=a) df2(in=b);

    if a and b then output inner_join;
    if a then output left_join;
    if b then output right_join;
    if a or b then output outer_join;
run;

# %% [markdown]
# ## Union

# %%
df1 = pd.DataFrame({"city": ["Chicago", "San Francisco", "New York City"], "rank": range(1, 4)})

df2 = pd.DataFrame({"city": ["Chicago", "Boston", "Los Angeles"], "rank": [1, 4, 5]})
display(df1)
display(df2)
# Out:
#             city  rank
# 0        Chicago     1
# 1  San Francisco     2
# 2  New York City     3
#           city  rank
# 0      Chicago     1
# 1       Boston     4
# 2  Los Angeles     5

# %%
#SQL
'''SELECT city, rank
FROM df1
UNION ALL
SELECT city, rank
FROM df2;'''
/*
         city  rank
      Chicago     1
San Francisco     2
New York City     3
      Chicago     1
       Boston     4
  Los Angeles     5
*/

# %%
#PYTHON
pd.concat([df1, df2])
# Out:
#             city  rank
# 0        Chicago     1
# 1  San Francisco     2
# 2  New York City     3
# 0        Chicago     1
# 1         Boston     4
# 2    Los Angeles     5

# %%
#SQL

'''SELECT city, rank
FROM df1
UNION
SELECT city, rank
FROM df2;'''
-- notice that there is only one Chicago record this time
/*
         city  rank
      Chicago     1
San Francisco     2
New York City     3
       Boston     4
  Los Angeles     5
*/

# %%
#PYTHON
pd.concat([df1, df2]).drop_duplicates()
# Out:
#             city  rank
# 0        Chicago     1
# 1  San Francisco     2
# 2  New York City     3
# 1         Boston     4
# 2    Los Angeles     5

# %%
#SAS

DATA TIPS_UNION;

SET TIPS TIPS;

RUN;


PROC SORT DATA = TIPS_UNION NODUP;
BY _all_;
RUN;

# %% [markdown]
# ## Limit

# %%
#SQL
'''SELECT * FROM tips
LIMIT 10;'''

# %%
#PYTHON
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
#SAS
proc print data=tips(obs=5);
run;

# %% [markdown]
# ## Top n rows with offset

# %%
'''SELECT * FROM tips
ORDER BY tip DESC
LIMIT 10 OFFSET 5;'''

# %%
tips.nlargest(10 + 5, columns="tip").tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 47        32.40  6.00    Male     No   Sun  Dinner     4
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 88        24.71  5.85    Male     No  Thur   Lunch     2
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2
# 44        30.40  5.60    Male     No   Sun  Dinner     4
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4

# %%
tips.nlargest(10, columns="tip").tail(10)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 239       29.03   5.92    Male     No   Sat  Dinner     3
# 88        24.71   5.85    Male     No  Thur   Lunch     2

# %% [markdown]
# ## Top n rows per group

# %%
'''-- Oracle's ROW_NUMBER() analytic function
SELECT * FROM (
  SELECT
    t.*,
    ROW_NUMBER() OVER(PARTITION BY day ORDER BY total_bill DESC) AS rn
  FROM tips t
) temp
WHERE rn < 3
ORDER BY day, rn'''

# %%
tips.assign(
        rn=tips.sort_values(["total_bill"], ascending=False)
    .groupby(["day"]).cumcount()+ 1).query("rn < 3").sort_values(["day", "rn"])
# Out:
#      total_bill    tip     sex smoker   day    time  size  rn
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4   1
# 90        28.97   3.00    Male    Yes   Fri  Dinner     2   2
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3   1
# 212       48.33   9.00    Male     No   Sat  Dinner     4   2
# 156       48.17   5.00    Male     No   Sun  Dinner     6   1
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3   2
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4   1
# 142       41.19   5.00    Male     No  Thur   Lunch     5   2

# %%
(
    tips.assign(
        rnk=tips.groupby(["day"])["total_bill"].rank(
            method="first", ascending=False
        )
    )
    .query("rnk < 3")
    .sort_values(["day", "rnk"])
)
# Out:
#      total_bill    tip     sex smoker   day    time  size  rnk
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4  1.0
# 90        28.97   3.00    Male    Yes   Fri  Dinner     2  2.0
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3  1.0
# 212       48.33   9.00    Male     No   Sat  Dinner     4  2.0
# 156       48.17   5.00    Male     No   Sun  Dinner     6  1.0
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3  2.0
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4  1.0
# 142       41.19   5.00    Male     No  Thur   Lunch     5  2.0

# %% [markdown]
# ## Update

# %%
'''UPDATE tips
SET tip = tip*2
WHERE tip < 2;'''

# %%
tips.loc[tips["tip"] < 2, "tip"] *= 2
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  2.02  Female     No   Sun  Dinner     2
# 1         10.34  3.32    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  3.50    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Delete

# %%
'''DELETE FROM tips
WHERE tip > 9;'''

# %%
tips=tips[tips["tip"] <= 9]
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  2.02  Female     No   Sun  Dinner     2
# 1         10.34  3.32    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  3.50    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %% [markdown]
# # 3 - Output

# %% [markdown]
# ## to csv

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_rate_12131
# 0         16.99  1.01  Female     No   Sun  Dinner     2        0.059447
# 1         10.34  1.66    Male     No   Sun  Dinner     3        0.160542
# 2         21.01  3.50    Male     No   Sun  Dinner     3        0.166587
# 3         23.68  3.31    Male     No   Sun  Dinner     2        0.139780
# 4         24.59  3.61  Female     No   Sun  Dinner     4        0.146808
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3        0.203927
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2        0.073584
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2        0.088222
# 242       17.82  1.75    Male     No   Sat  Dinner     2        0.098204
# 243       18.78  3.00  Female     No  Thur  Dinner     2        0.159744
#
# [244 rows x 8 columns]

# %%
#python
tips.to_csv("tips2.csv")

# %%
#SAS
proc export data=tips outfile='tips2.csv' dbms=csv;
run;

# %% [markdown]
# ## to database

# %%
#python
tips.to_sql('tips_output_3',engine_datahub,if_exists='replace',index=False)
