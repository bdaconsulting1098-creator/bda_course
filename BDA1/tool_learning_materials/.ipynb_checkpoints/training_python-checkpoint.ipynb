# %% [markdown]
# # Python Training
# # Contents
# - [Import modules](#Import-modules)
# - [Object Creation](#Object-Creation)
# - [Viewing Data](#Viewing-Data)
# - [Selection](#Selection)
# - [Selection by Position](#Selection-by-Position)
# - [Boolean Indexing](#Boolean-Indexing)
# - [Setting](#Setting)
# - [Missing Data](#Missing-Data)
# - [Operations](#Operations)
# - [Merge](#Merge)
# - [Grouping](#Grouping)
# - [Reshaping](#Reshaping)
# - [Time Series](#Time-Series)
# - [Categoricals](#Categoricals)
# - [Time Series](#Time-Series)
# - [Plotting](#Plotting)
# - [Getting Data In/Out](#Getting-Data-In/Out)
# - [Error Handling](#Error-Handling)

# %% [markdown]
# # Import modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Object Creation
#  Creating a Series by passing a list of values, letting pandas create a default integer index:

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Creating a [DataFrame] by passing a numpy array, with a datetime index and labeled columns:

# %%
dates = pd.date_range('20141101', periods=6)
dates
# Out:
# DatetimeIndex(['2014-11-01', '2014-11-02', '2014-11-03', '2014-11-04',
#                '2014-11-05', '2014-11-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
np.random.randn(6,4)
# Out:
# array([[-0.10795267, -0.06341126,  0.51513222, -1.05239625],
#        [ 0.06707601, -2.44240591, -1.01585805,  0.53132347],
#        [ 1.726208  , -1.73474768, -0.1855514 ,  0.73365404],
#        [ 0.97365548, -1.16046464,  0.57406963,  0.72066937],
#        [-1.22413079,  0.67277864,  0.1356297 , -3.04492277],
#        [ 0.31625049, -1.55425024, -1.31468725,  0.64034606]])

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates,columns=['one','two','three','four'])
df
# Out:
#                  one       two     three      four
# 2014-11-01 -1.699057  0.211477  1.321046 -0.846100
# 2014-11-02 -0.047963  1.620238  0.654495 -1.185293
# 2014-11-03  0.230596 -0.989060 -0.532018  0.694357
# 2014-11-04 -0.368522  0.473925 -1.784301 -2.142998
# 2014-11-05  0.400525  0.004858  0.281328 -0.594767
# 2014-11-06 -0.348054  1.281238  1.025318  0.607553

# %% [markdown]
# Creating a DataFrame by passing a dict of objects that can be converted to series-like.

# %%
df2 = pd.DataFrame({ 'A' : 1.,
   ....:                      'B' : pd.Timestamp('20130102'),
   ....:                      'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
   ....:                      'D' : np.array([3] * 4,dtype='int32'),
   ....:                      'E' : pd.Categorical(["test","train","test","train"]),
   ....:                      'F' : 'foo' })
   ....: 
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# Having specific [dtypes]:

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# # Viewing Data
# See the top & bottom rows of the frame

# %%
df.head()
# Out:
#                  one       two     three      four
# 2014-11-01 -1.699057  0.211477  1.321046 -0.846100
# 2014-11-02 -0.047963  1.620238  0.654495 -1.185293
# 2014-11-03  0.230596 -0.989060 -0.532018  0.694357
# 2014-11-04 -0.368522  0.473925 -1.784301 -2.142998
# 2014-11-05  0.400525  0.004858  0.281328 -0.594767

# %%
df.tail(3)
# Out:
#                  one       two     three      four
# 2014-11-04 -0.368522  0.473925 -1.784301 -2.142998
# 2014-11-05  0.400525  0.004858  0.281328 -0.594767
# 2014-11-06 -0.348054  1.281238  1.025318  0.607553

# %% [markdown]
# Display the index, columns, and the underlying numpy data

# %%
df.index
# Out:
# DatetimeIndex(['2014-11-01', '2014-11-02', '2014-11-03', '2014-11-04',
#                '2014-11-05', '2014-11-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['one', 'two', 'three', 'four'], dtype='object')

# %%
df.values
# Out:
# array([[-1.69905745,  0.21147674,  1.32104598, -0.84610031],
#        [-0.04796318,  1.62023848,  0.65449519, -1.18529297],
#        [ 0.23059551, -0.98905956, -0.53201804,  0.69435667],
#        [-0.3685222 ,  0.47392476, -1.78430111, -2.14299809],
#        [ 0.40052518,  0.00485811,  0.28132824, -0.59476699],
#        [-0.3480543 ,  1.28123841,  1.02531754,  0.60755342]])

# %% [markdown]
# Describe shows a quick statistic summary of your data

# %%
df.describe()
# Out:
#             one       two     three      four
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.305413  0.433779  0.160978 -0.577875
# std    0.748329  0.936520  1.150238  1.087622
# min   -1.699057 -0.989060 -1.784301 -2.142998
# 25%   -0.363405  0.056513 -0.328681 -1.100495
# 50%   -0.198009  0.342701  0.467912 -0.720434
# 75%    0.160956  1.079410  0.932612  0.306973
# max    0.400525  1.620238  1.321046  0.694357

# %% [markdown]
# Transposing your data

# %%
df.T
# Out:
#        2014-11-01  2014-11-02  2014-11-03  2014-11-04  2014-11-05  2014-11-06
# one     -1.699057   -0.047963    0.230596   -0.368522    0.400525   -0.348054
# two      0.211477    1.620238   -0.989060    0.473925    0.004858    1.281238
# three    1.321046    0.654495   -0.532018   -1.784301    0.281328    1.025318
# four    -0.846100   -1.185293    0.694357   -2.142998   -0.594767    0.607553

# %% [markdown]
# Sorting by an axis (In this case, sorting the columns in reverse alphabetical order):

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                  two     three       one      four
# 2014-11-01  0.211477  1.321046 -1.699057 -0.846100
# 2014-11-02  1.620238  0.654495 -0.047963 -1.185293
# 2014-11-03 -0.989060 -0.532018  0.230596  0.694357
# 2014-11-04  0.473925 -1.784301 -0.368522 -2.142998
# 2014-11-05  0.004858  0.281328  0.400525 -0.594767
# 2014-11-06  1.281238  1.025318 -0.348054  0.607553

# %% [markdown]
# Sorting by values

# %%
df.sort_values(by='two')
# Out:
#                  one       two     three      four
# 2014-11-03  0.230596 -0.989060 -0.532018  0.694357
# 2014-11-05  0.400525  0.004858  0.281328 -0.594767
# 2014-11-01 -1.699057  0.211477  1.321046 -0.846100
# 2014-11-04 -0.368522  0.473925 -1.784301 -2.142998
# 2014-11-06 -0.348054  1.281238  1.025318  0.607553
# 2014-11-02 -0.047963  1.620238  0.654495 -1.185293

# %% [markdown]
# # Selection

# %% [markdown]
# Note While standard Python / Numpy expressions for selecting and setting are intuitive and come in handy for interactive work, for production code, we recommend the optimized pandas data access methods, .at, .iat, .loc, .iloc and .ix.

# %% [markdown]
# ## Getting

# %% [markdown]
# Selecting a single column, which yields a Series, equivalent to df.one

# %%
df['one']
# Out:
# 2014-11-01   -1.699057
# 2014-11-02   -0.047963
# 2014-11-03    0.230596
# 2014-11-04   -0.368522
# 2014-11-05    0.400525
# 2014-11-06   -0.348054
# Freq: D, Name: one, dtype: float64

# %%
df.one
# Out:
# 2014-11-01   -1.699057
# 2014-11-02   -0.047963
# 2014-11-03    0.230596
# 2014-11-04   -0.368522
# 2014-11-05    0.400525
# 2014-11-06   -0.348054
# Freq: D, Name: one, dtype: float64

# %% [markdown]
# Selecting via [], which slices the rows.

# %%
df[0:3]
# Out:
#                  one       two     three      four
# 2014-11-01 -1.699057  0.211477  1.321046 -0.846100
# 2014-11-02 -0.047963  1.620238  0.654495 -1.185293
# 2014-11-03  0.230596 -0.989060 -0.532018  0.694357

# %%
df['20141102':'20141104']
# Out:
#                  one       two     three      four
# 2014-11-02 -0.047963  1.620238  0.654495 -1.185293
# 2014-11-03  0.230596 -0.989060 -0.532018  0.694357
# 2014-11-04 -0.368522  0.473925 -1.784301 -2.142998

# %% [markdown]
# ## Selecting by Label

# %% [markdown]
# For getting a cross section using a label

# %%
df.loc[dates[0]]
# Out:
# one     -1.699057
# two      0.211477
# three    1.321046
# four    -0.846100
# Name: 2014-11-01 00:00:00, dtype: float64

# %% [markdown]
# Selecting on a multi-axis by label

# %%
df.loc[:,['one','two']]
# Out:
#                  one       two
# 2014-11-01 -1.699057  0.211477
# 2014-11-02 -0.047963  1.620238
# 2014-11-03  0.230596 -0.989060
# 2014-11-04 -0.368522  0.473925
# 2014-11-05  0.400525  0.004858
# 2014-11-06 -0.348054  1.281238

# %% [markdown]
# Showing label slicing, both endpoints are included

# %%
df.loc['20141102':'20141104',['one','two']]
# Out:
#                  one       two
# 2014-11-02 -0.047963  1.620238
# 2014-11-03  0.230596 -0.989060
# 2014-11-04 -0.368522  0.473925

# %% [markdown]
# Reduction in the dimensions of the returned object

# %%
df.loc['20141102',['one','two']]
# Out:
# one   -0.047963
# two    1.620238
# Name: 2014-11-02 00:00:00, dtype: float64

# %% [markdown]
# For getting a scalar value

# %%
df.loc[dates[0],'one']
# Out:
# -1.699057450830497

# %% [markdown]
# For getting fast access to a scalar (equiv to the prior method)

# %%
df.at[dates[0],'one']
# Out:
# -1.699057450830497

# %% [markdown]
# ## Selection by Position

# %% [markdown]
# See more in [Selection by Position](Selection by Position)
#
# Select via the position of the passed integers

# %%
df.iloc[3]
# Out:
# one     -0.368522
# two      0.473925
# three   -1.784301
# four    -2.142998
# Name: 2014-11-04 00:00:00, dtype: float64

# %% [markdown]
# By integer slices, acting similar to numpy/python

# %% [markdown]
# By lists of integer position locations, similar to the numpy/python style

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                  one     three
# 2014-11-02 -0.047963  0.654495
# 2014-11-03  0.230596 -0.532018
# 2014-11-05  0.400525  0.281328

# %% [markdown]
# For slicing rows explicitly

# %%
df.iloc[1:3,:]
# Out:
#                  one       two     three      four
# 2014-11-02 -0.047963  1.620238  0.654495 -1.185293
# 2014-11-03  0.230596 -0.989060 -0.532018  0.694357

# %% [markdown]
# For slicing columns explicitly

# %%
df.iloc[:,1:3]
# Out:
#                  two     three
# 2014-11-01  0.211477  1.321046
# 2014-11-02  1.620238  0.654495
# 2014-11-03 -0.989060 -0.532018
# 2014-11-04  0.473925 -1.784301
# 2014-11-05  0.004858  0.281328
# 2014-11-06  1.281238  1.025318

# %% [markdown]
# For getting a value explicitly

# %%
df.iloc[1,1]
# Out:
# 1.6202384817210749

# %% [markdown]
# For getting fast access to a scalar (equiv to the prior method)

# %%
df.iat[0,0]
# Out:
# -1.699057450830497

# %% [markdown]
# ## Boolean Indexing
# Using a single column’s values to select data.

# %%
df[df.one > 0.5]
# Out:
# Empty DataFrame
# Columns: [one, two, three, four]
# Index: []

# %% [markdown]
# Selecting values from a DataFrame where a boolean condition is met.

# %%
df[df>0]
# Out:
#                  one       two     three      four
# 2014-11-01       NaN  0.211477  1.321046       NaN
# 2014-11-02       NaN  1.620238  0.654495       NaN
# 2014-11-03  0.230596       NaN       NaN  0.694357
# 2014-11-04       NaN  0.473925       NaN       NaN
# 2014-11-05  0.400525  0.004858  0.281328       NaN
# 2014-11-06       NaN  1.281238  1.025318  0.607553

# %% [markdown]
# Using the isin method for filtering:

# %%
df2 = df.copy()
df2['five'] = ['one', 'one','two','three','four','three']
df2
# Out:
#                  one       two     three      four   five
# 2014-11-01 -1.699057  0.211477  1.321046 -0.846100    one
# 2014-11-02 -0.047963  1.620238  0.654495 -1.185293    one
# 2014-11-03  0.230596 -0.989060 -0.532018  0.694357    two
# 2014-11-04 -0.368522  0.473925 -1.784301 -2.142998  three
# 2014-11-05  0.400525  0.004858  0.281328 -0.594767   four
# 2014-11-06 -0.348054  1.281238  1.025318  0.607553  three

# %%
df2[df2['five'].isin(['two','four'])]
# Out:
#                  one       two     three      four  five
# 2014-11-03  0.230596 -0.989060 -0.532018  0.694357   two
# 2014-11-05  0.400525  0.004858  0.281328 -0.594767  four

# %% [markdown]
# ## Setting
# Setting a new column automatically aligns the data by the indexes

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20141101', periods=6))
s1
# Out:
# 2014-11-01    1
# 2014-11-02    2
# 2014-11-03    3
# 2014-11-04    4
# 2014-11-05    5
# 2014-11-06    6
# Freq: D, dtype: int64

# %%
df['six'] = s1
df
# Out:
#                  one       two     three      four  six
# 2014-11-01 -1.699057  0.211477  1.321046 -0.846100    1
# 2014-11-02 -0.047963  1.620238  0.654495 -1.185293    2
# 2014-11-03  0.230596 -0.989060 -0.532018  0.694357    3
# 2014-11-04 -0.368522  0.473925 -1.784301 -2.142998    4
# 2014-11-05  0.400525  0.004858  0.281328 -0.594767    5
# 2014-11-06 -0.348054  1.281238  1.025318  0.607553    6

# %% [markdown]
# Setting values by label:

# %%
df.at[dates[0],'one'] = 0
df
# Out:
#                  one       two     three      four  six
# 2014-11-01  0.000000  0.211477  1.321046 -0.846100    1
# 2014-11-02 -0.047963  1.620238  0.654495 -1.185293    2
# 2014-11-03  0.230596 -0.989060 -0.532018  0.694357    3
# 2014-11-04 -0.368522  0.473925 -1.784301 -2.142998    4
# 2014-11-05  0.400525  0.004858  0.281328 -0.594767    5
# 2014-11-06 -0.348054  1.281238  1.025318  0.607553    6

# %% [markdown]
# Setting values by position:

# %%
df.iat[0,1] = 0
df
# Out:
#                  one       two     three      four  six
# 2014-11-01  0.000000  0.000000  1.321046 -0.846100    1
# 2014-11-02 -0.047963  1.620238  0.654495 -1.185293    2
# 2014-11-03  0.230596 -0.989060 -0.532018  0.694357    3
# 2014-11-04 -0.368522  0.473925 -1.784301 -2.142998    4
# 2014-11-05  0.400525  0.004858  0.281328 -0.594767    5
# 2014-11-06 -0.348054  1.281238  1.025318  0.607553    6

# %%
df.loc[:,'four'] = np.array([5] * len(df))
df
# Out:
#                  one       two     three  four  six
# 2014-11-01  0.000000  0.000000  1.321046     5    1
# 2014-11-02 -0.047963  1.620238  0.654495     5    2
# 2014-11-03  0.230596 -0.989060 -0.532018     5    3
# 2014-11-04 -0.368522  0.473925 -1.784301     5    4
# 2014-11-05  0.400525  0.004858  0.281328     5    5
# 2014-11-06 -0.348054  1.281238  1.025318     5    6

# %% [markdown]
# A where operation with setting.

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                  one       two     three  four  six
# 2014-11-01  0.000000  0.000000 -1.321046    -5   -1
# 2014-11-02 -0.047963 -1.620238 -0.654495    -5   -2
# 2014-11-03 -0.230596 -0.989060 -0.532018    -5   -3
# 2014-11-04 -0.368522 -0.473925 -1.784301    -5   -4
# 2014-11-05 -0.400525 -0.004858 -0.281328    -5   -5
# 2014-11-06 -0.348054 -1.281238 -1.025318    -5   -6

# %% [markdown]
# ## Missing Data
# pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations. See the
#
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data.

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1],'E'] = 1
df1
# Out:
#                  one       two     three  four  six    E
# 2014-11-01  0.000000  0.000000  1.321046     5    1  1.0
# 2014-11-02 -0.047963  1.620238  0.654495     5    2  1.0
# 2014-11-03  0.230596 -0.989060 -0.532018     5    3  NaN
# 2014-11-04 -0.368522  0.473925 -1.784301     5    4  NaN

# %% [markdown]
# To drop any rows that have missing data:

# %%
df1.dropna(how='any')
# Out:
#                  one       two     three  four  six    E
# 2014-11-01  0.000000  0.000000  1.321046     5    1  1.0
# 2014-11-02 -0.047963  1.620238  0.654495     5    2  1.0

# %% [markdown]
# Filling missing data:

# %%
df1.fillna(value=5)
# Out:
#                  one       two     three  four  six    E
# 2014-11-01  0.000000  0.000000  1.321046     5    1  1.0
# 2014-11-02 -0.047963  1.620238  0.654495     5    2  1.0
# 2014-11-03  0.230596 -0.989060 -0.532018     5    3  5.0
# 2014-11-04 -0.368522  0.473925 -1.784301     5    4  5.0

# %% [markdown]
# ## Operations

# %% [markdown]
# ### Stats
# Operations in general *exclude* missing data.
#
# Performing a descriptive statistic:

# %%
df.mean()
# Out:
# one     -0.022236
# two      0.398533
# three    0.160978
# four     5.000000
# six      3.500000
# dtype: float64

# %% [markdown]
# Same operation on the other axis:

# %%
df.mean(1)
# Out:
# 2014-11-01    1.464209
# 2014-11-02    1.845354
# 2014-11-03    1.341904
# 2014-11-04    1.464220
# 2014-11-05    2.137342
# 2014-11-06    2.591700
# Freq: D, dtype: float64

# %% [markdown]
# Operating with objects that have different dimensionality and need alignment. In addition, pandas automatically broadcasts along the specified dimension. The following code also shifts the data vertically, leaving NaN values in the unoccupied spaces

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2)
s
# Out:
# 2014-11-01    NaN
# 2014-11-02    NaN
# 2014-11-03    1.0
# 2014-11-04    3.0
# 2014-11-05    5.0
# 2014-11-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                  one       two     three  four  six
# 2014-11-01       NaN       NaN       NaN   NaN  NaN
# 2014-11-02       NaN       NaN       NaN   NaN  NaN
# 2014-11-03 -0.769404 -1.989060 -1.532018   4.0  2.0
# 2014-11-04 -3.368522 -2.526075 -4.784301   2.0  1.0
# 2014-11-05 -4.599475 -4.995142 -4.718672   0.0  0.0
# 2014-11-06       NaN       NaN       NaN   NaN  NaN

# %% [markdown]
# ### Apply
# Applying functions to the data

# %%
df.apply(np.cumsum)
# Out:
#                  one       two     three  four  six
# 2014-11-01  0.000000  0.000000  1.321046     5    1
# 2014-11-02 -0.047963  1.620238  1.975541    10    3
# 2014-11-03  0.182632  0.631179  1.443523    15    6
# 2014-11-04 -0.185890  1.105104 -0.340778    20   10
# 2014-11-05  0.214635  1.109962 -0.059450    25   15
# 2014-11-06 -0.133419  2.391200  0.965868    30   21

# %% [markdown]
# ### Histogramming

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    0
# 1    3
# 2    4
# 3    4
# 4    3
# 5    6
# 6    5
# 7    5
# 8    2
# 9    5
# dtype: int32

# %%
s.value_counts()
# Out:
# 5    3
# 3    2
# 4    2
# 0    1
# 6    1
# 2    1
# dtype: int64

# %% [markdown]
# ### String Methods
# Series is equipped with a set of string processing methods in the str attribute that make it easy to operate on each element of the array, as in the code snippet below. Note that pattern-matching in str generally uses [regular expressions]

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# # Merge
# ### Concat
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -0.115856 -0.227171  1.551302  0.378369
# 1  0.632208  0.421713 -0.448995  1.171032
# 2  1.447728  0.378573 -0.391214 -0.460602
# 3  0.166452  1.848208  1.016342  0.162104
# 4  0.043572  0.531137 -1.107881  0.595332
# 5 -0.787384 -0.501641  0.743642 -1.038472
# 6  1.713848 -0.466134 -1.531377  0.206179
# 7  0.379524  1.244460 -0.556318 -1.275893
# 8  0.834618  0.893540  1.165568  1.439990
# 9  0.849649 -0.296356 -1.465935 -0.181495

# %%
#break it into pieces:
pieces = [df[:3], df[3:7], df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0 -0.115856 -0.227171  1.551302  0.378369
#  1  0.632208  0.421713 -0.448995  1.171032
#  2  1.447728  0.378573 -0.391214 -0.460602,
#            0         1         2         3
#  3  0.166452  1.848208  1.016342  0.162104
#  4  0.043572  0.531137 -1.107881  0.595332
#  5 -0.787384 -0.501641  0.743642 -1.038472
#  6  1.713848 -0.466134 -1.531377  0.206179,
#            0         1         2         3
#  7  0.379524  1.244460 -0.556318 -1.275893
#  8  0.834618  0.893540  1.165568  1.439990
#  9  0.849649 -0.296356 -1.465935 -0.181495]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.115856 -0.227171  1.551302  0.378369
# 1  0.632208  0.421713 -0.448995  1.171032
# 2  1.447728  0.378573 -0.391214 -0.460602
# 3  0.166452  1.848208  1.016342  0.162104
# 4  0.043572  0.531137 -1.107881  0.595332
# 5 -0.787384 -0.501641  0.743642 -1.038472
# 6  1.713848 -0.466134 -1.531377  0.206179
# 7  0.379524  1.244460 -0.556318 -1.275893
# 8  0.834618  0.893540  1.165568  1.439990
# 9  0.849649 -0.296356 -1.465935 -0.181495

# %% [markdown]
# ### Join

# %% [markdown]
# SQL style merges.

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left,right,on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %% [markdown]
# Another example that can be given is:

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# ### Append
# Append rows to a dataframe.

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0 -0.171026 -0.950323 -1.015400  2.528927
# 1 -0.137029 -0.878913 -1.732760 -0.448583
# 2 -1.459129 -2.109077 -2.319378  0.591910
# 3  0.851537  0.341302 -0.126066  0.301870
# 4 -0.237734  0.296823 -0.319041  0.515752
# 5  0.870707  1.467847 -0.576614  0.146614
# 6  2.408953 -0.910308 -1.810733  0.558373
# 7 -1.003227 -0.292690 -0.300241  0.026397

# %%
s = df.iloc[3]
s
# Out:
# A    0.851537
# B    0.341302
# C   -0.126066
# D    0.301870
# Name: 3, dtype: float64

# %%
df.append(s,ignore_index=True)
# Out:
#           A         B         C         D
# 0 -0.171026 -0.950323 -1.015400  2.528927
# 1 -0.137029 -0.878913 -1.732760 -0.448583
# 2 -1.459129 -2.109077 -2.319378  0.591910
# 3  0.851537  0.341302 -0.126066  0.301870
# 4 -0.237734  0.296823 -0.319041  0.515752
# 5  0.870707  1.467847 -0.576614  0.146614
# 6  2.408953 -0.910308 -1.810733  0.558373
# 7 -1.003227 -0.292690 -0.300241  0.026397
# 8  0.851537  0.341302 -0.126066  0.301870

# %% [markdown]
# # Grouping
# By “group by” we are referring to a process involving one or more of the following steps
#
# Splitting the data into groups based on some criteria
# Applying a function to each group independently
# Combining the results into a data structure

# %%
df = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
   ....:                           'foo', 'bar', 'foo', 'foo'],
   ....:                    'B' : ['one', 'one', 'two', 'three',
   ....:                           'two', 'two', 'one', 'three'],
   ....:                    'C' : np.random.randn(8),
   ....:                    'D' : np.random.randn(8)})
df
# Out:
#      A      B         C         D
# 0  foo    one -1.158015 -0.522762
# 1  bar    one  0.506577 -0.155553
# 2  foo    two  0.301670  1.534366
# 3  bar  three -0.381944 -0.287205
# 4  foo    two  0.400848 -1.114236
# 5  bar    two  0.133257  1.324005
# 6  foo    one  0.129274  0.965340
# 7  foo  three  1.271630  1.036408

# %% [markdown]
# Grouping and then applying a function sum to the resulting groups.

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  0.257890  0.881247
# foo  0.945406  1.899116

# %% [markdown]
# Grouping by multiple columns forms a hierarchical index, which we then apply the function.

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.506577 -0.155553
#     three -0.381944 -0.287205
#     two    0.133257  1.324005
# foo one   -1.028741  0.442578
#     three  1.271630  1.036408
#     two    0.702518  0.420129

# %% [markdown]
# # Reshaping
#
#
# ### Stack

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
   ....:                      'foo', 'foo', 'qux', 'qux'],
   ....:                     ['one', 'two', 'one', 'two',
   ....:                      'one', 'two', 'one', 'two']]))
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df
# Out:
#                      A         B
# first second
# bar   one    -0.244120  0.462231
#       two     1.649850  0.507299
# baz   one     1.341394 -0.244970
#       two    -0.090372 -0.973879
# foo   one    -0.145459 -0.585266
#       two    -0.815631 -1.115950
# qux   one    -0.881082  0.376042
#       two    -1.173539 -0.316075

# %% [markdown]
# The [stack()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.stack.html#pandas.DataFrame.stack) method “compresses” a level in the DataFrame’s columns.

# %%
stacked = df.stack()
stacked
# Out:
# first  second
# bar    one     A   -0.244120
#                B    0.462231
#        two     A    1.649850
#                B    0.507299
# baz    one     A    1.341394
#                B   -0.244970
#        two     A   -0.090372
#                B   -0.973879
# foo    one     A   -0.145459
#                B   -0.585266
#        two     A   -0.815631
#                B   -1.115950
# qux    one     A   -0.881082
#                B    0.376042
#        two     A   -1.173539
#                B   -0.316075
# dtype: float64

# %% [markdown]
# With a “stacked” DataFrame or Series (having a MultiIndex as the index), the inverse operation of [stack()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.stack.html#pandas.DataFrame.stack) is [unstack()](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.unstack.html#pandas.DataFrame.unstack), which by default unstacks the last level:

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.244120  0.462231
#       two     1.649850  0.507299
# baz   one     1.341394 -0.244970
#       two    -0.090372 -0.973879
# foo   one    -0.145459 -0.585266
#       two    -0.815631 -1.115950
# qux   one    -0.881082  0.376042
#       two    -1.173539 -0.316075

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.244120  1.649850
#       B  0.462231  0.507299
# baz   A  1.341394 -0.090372
#       B -0.244970 -0.973879
# foo   A -0.145459 -0.815631
#       B -0.585266 -1.115950
# qux   A -0.881082 -1.173539
#       B  0.376042 -0.316075

# %%
stacked.unstack(0)
# Out:
# first          bar       baz       foo       qux
# second
# one    A -0.244120  1.341394 -0.145459 -0.881082
#        B  0.462231 -0.244970 -0.585266  0.376042
# two    A  1.649850 -0.090372 -0.815631 -1.173539
#        B  0.507299 -0.973879 -1.115950 -0.316075

# %% [markdown]
# ### Pivot Tables

# %%
df = pd.DataFrame({'A' : ['one', 'one', 'two', 'three'] * 3,
   .....:                    'B' : ['A', 'B', 'C'] * 4,
   .....:                    'C' : ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
   .....:                    'D' : np.random.randn(12),
   .....:                    'E' : np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -2.084891 -0.162297
# 1     one  B  foo -0.438962 -0.589064
# 2     two  C  foo  0.248165  0.871776
# 3   three  A  bar  0.802608  0.640574
# 4     one  B  bar -1.408780  0.843575
# 5     one  C  bar  0.108143  2.774181
# 6     two  A  foo  0.186834  0.945580
# 7   three  B  foo -0.908669 -0.264096
# 8     one  C  foo -1.861348 -0.840777
# 9     one  A  bar  0.524805 -0.357180
# 10    two  B  bar -1.382453 -0.845661
# 11  three  C  bar  0.358264 -1.045926

# %% [markdown]
# We can produce pivot tables from this data very easily:

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A  0.524805 -2.084891
#       B -1.408780 -0.438962
#       C  0.108143 -1.861348
# three A  0.802608       NaN
#       B       NaN -0.908669
#       C  0.358264       NaN
# two   A       NaN  0.186834
#       B -1.382453       NaN
#       C       NaN  0.248165

# %% [markdown]
# # Time Series
# pandas has simple, powerful, and efficient functionality for performing resampling operations during frequency conversion (e.g., converting secondly data into 5-minutely data). This is extremely common in, but not limited to, financial applications.

# %%
rng = pd.date_range('1/1/2017', periods=100, freq='S')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample('5Min').sum()
# Out:
# 2017-01-01    22004
# Freq: 5T, dtype: int32

# %% [markdown]
# Time zone representation

# %%
rng = pd.date_range('3/6/2017 00:00', periods=5, freq='D')
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2017-03-06    0.824722
# 2017-03-07   -1.173824
# 2017-03-08    0.084371
# 2017-03-09    0.056655
# 2017-03-10    0.757457
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')
ts_utc
# Out:
# 2017-03-06 00:00:00+00:00    0.824722
# 2017-03-07 00:00:00+00:00   -1.173824
# 2017-03-08 00:00:00+00:00    0.084371
# 2017-03-09 00:00:00+00:00    0.056655
# 2017-03-10 00:00:00+00:00    0.757457
# Freq: D, dtype: float64

# %% [markdown]
# Convert to another time zone

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2017-03-05 19:00:00-05:00    0.824722
# 2017-03-06 19:00:00-05:00   -1.173824
# 2017-03-07 19:00:00-05:00    0.084371
# 2017-03-08 19:00:00-05:00    0.056655
# 2017-03-09 19:00:00-05:00    0.757457
# Freq: D, dtype: float64

# %% [markdown]
# Converting between time span representations

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')
ts = pd.Series(np.random.randn(len(rng)), index=rng)
ts
# Out:
# 2012-01-31    1.613562
# 2012-02-29   -0.789248
# 2012-03-31    0.685736
# 2012-04-30    0.184306
# 2012-05-31   -0.881959
# Freq: M, dtype: float64

# %%
ps = ts.to_period('M')
ps
# Out:
# 2012-01    1.613562
# 2012-02   -0.789248
# 2012-03    0.685736
# 2012-04    0.184306
# 2012-05   -0.881959
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    1.613562
# 2012-02-01   -0.789248
# 2012-03-01    0.685736
# 2012-04-01    0.184306
# 2012-05-01   -0.881959
# Freq: MS, dtype: float64

# %% [markdown]
# Converting between period and timestamp enables some convenient arithmetic functions to be used. In the following example, we convert a quarterly frequency with year ending in November to 9am of the end of the month following the quarter end:

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')
ts = pd.Series(np.random.randn(len(prng)), prng)
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9
ts.head()
# Out:
# 1990-03-01 09:00    0.362599
# 1990-06-01 09:00    2.537181
# 1990-09-01 09:00    0.227528
# 1990-12-01 09:00   -0.429090
# 1991-03-01 09:00    1.008351
# Freq: H, dtype: float64

# %% [markdown]
# # Categoricals
# pandas can include categorical data in a DataFrame.

# %%
df = pd.DataFrame({"id":[1,2,3,4,5,6], "raw_grade":['a', 'b', 'b', 'a', 'a', 'e']})
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %% [markdown]
# Convert the raw grades to a categorical data type:

# %%
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %% [markdown]
# Rename the categories to more meaningful names (assigning to Series.cat.categories is inplace!)

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %% [markdown]
# Reorder the categories and simultaneously add the missing categories (methods under Series .cat return a new Series per default).

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium", "good", "very good"])
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %% [raw]
# Sorting is per order in the categories, not lexical order.

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %% [markdown]
# Grouping by a categorical column shows also empty categories.

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# # Plotting

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# On DataFrame, plot() is a convenience to plot all of the columns with labels:

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
   .....:                   columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); df.plot(); plt.legend(loc='best')

# %% [markdown]
# # Getting Data In/Out
# ### CSV

# %%
df.to_csv('foo.csv')

# %%
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0         A          B          C          D
# 0    2000-01-01 -0.314900  -0.682112  -0.194254  -0.397533
# 1    2000-01-02 -1.189408   1.812425   1.237195   1.091248
# 2    2000-01-03 -1.278759   1.913797  -0.113042   1.254399
# 3    2000-01-04 -0.126188   0.942328  -0.542915   1.261482
# 4    2000-01-05  1.401159   0.119523   1.253997   3.081930
# ..          ...       ...        ...        ...        ...
# 995  2002-09-22 -4.335223  -9.690179  53.956852  30.580034
# 996  2002-09-23 -3.739584  -9.725423  54.772618  29.832408
# 997  2002-09-24 -4.741559  -8.995924  53.940261  30.139618
# 998  2002-09-25 -7.348678 -10.268341  52.939351  30.472613
# 999  2002-09-26 -6.853582  -9.739392  52.579765  29.507858
#
# [1000 rows x 5 columns]

# %% [markdown]
# ### HDF5
#
#
# Writing to a HDF5 Store:

# %%
df.to_hdf('foo.h5','df')

# %% [markdown]
# Reading from a HDF5 Store:

# %%
pd.read_hdf('foo.h5','df')
# Out:
#                    A          B          C          D
# 2000-01-01 -0.314900  -0.682112  -0.194254  -0.397533
# 2000-01-02 -1.189408   1.812425   1.237195   1.091248
# 2000-01-03 -1.278759   1.913797  -0.113042   1.254399
# 2000-01-04 -0.126188   0.942328  -0.542915   1.261482
# 2000-01-05  1.401159   0.119523   1.253997   3.081930
# ...              ...        ...        ...        ...
# 2002-09-22 -4.335223  -9.690179  53.956852  30.580034
# 2002-09-23 -3.739584  -9.725423  54.772618  29.832408
# 2002-09-24 -4.741559  -8.995924  53.940261  30.139618
# 2002-09-25 -7.348678 -10.268341  52.939351  30.472613
# 2002-09-26 -6.853582  -9.739392  52.579765  29.507858
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### Excel
#
#
# Writing to an excel file:

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %% [markdown]
# Reading from an excel file:

# %%
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# Out:
#     Unnamed: 0         A          B          C          D
# 0   2000-01-01 -0.314900  -0.682112  -0.194254  -0.397533
# 1   2000-01-02 -1.189408   1.812425   1.237195   1.091248
# 2   2000-01-03 -1.278759   1.913797  -0.113042   1.254399
# 3   2000-01-04 -0.126188   0.942328  -0.542915   1.261482
# 4   2000-01-05  1.401159   0.119523   1.253997   3.081930
# ..         ...       ...        ...        ...        ...
# 995 2002-09-22 -4.335223  -9.690179  53.956852  30.580034
# 996 2002-09-23 -3.739584  -9.725423  54.772618  29.832408
# 997 2002-09-24 -4.741559  -8.995924  53.940261  30.139618
# 998 2002-09-25 -7.348678 -10.268341  52.939351  30.472613
# 999 2002-09-26 -6.853582  -9.739392  52.579765  29.507858
#
# [1000 rows x 5 columns]

# %% [markdown]
# # Error Handling
# If you are trying an operation and you see an exception like:

# %%
if pd.Series([False, True, False]):
    print("I was true")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14908/2648304181.py in <module>
# ----> 1 if pd.Series([False, True, False]):
#       2     print("I was true")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
